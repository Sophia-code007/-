# %%
import requests
from bs4 import BeautifulSoup
import csv
import time
import os
import re
import random
import traceback

# 设置基础URL
base_url = "https://www.ricedata.cn/variety/"

# 创建保存数据的目录
if not os.path.exists('rice_data'):
    os.makedirs('rice_data')

# 全局请求头
REQUEST_HEADERS = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36',
    'Referer': base_url + 'index.htm'
}

def get_province_codes():
    """获取所有省份的特殊代号"""
    try:
        print("正在获取省份列表...")
        response = requests.get(base_url + "index.htm", headers=REQUEST_HEADERS)
        
        # 动态检测编码
        if response.encoding == 'ISO-8859-1':
            # 尝试常见中文编码
            for encoding in ['gbk', 'gb2312', 'utf-8']:
                try:
                    response.encoding = encoding
                    soup = BeautifulSoup(response.text, 'html.parser')
                    # 检查是否有中文内容
                    if '水稻' in soup.text:
                        print(f"使用编码: {encoding}")
                        break
                except:
                    continue
        
        if response.status_code != 200:
            print(f"请求失败，状态码: {response.status_code}")
            return {}
        
        soup = BeautifulSoup(response.text, 'html.parser')
        provinces = {}

        # 查找所有包含省份链接的a标签
        for link in soup.find_all('a', href=True):
            href = link['href']
            if href.startswith("identified/"):
                province_name = link.get_text(strip=True)
                match = re.search(r'identified/(.*?)_', href)
                if match:
                    code = match.group(1)
                    provinces[province_name] = code
                    print(f"找到省份: {province_name} ({code})")
        
        print(f"共找到 {len(provinces)} 个省份/部门")
        return provinces
    except Exception as e:
        print(f"获取省份代号失败: {e}")
        return {}

def get_total_pages(province_code):
    """获取指定省份的总页数 - 优化页码提取逻辑"""
    try:
        first_page_url = f"{base_url}identified/{province_code}_1.htm"
        print(f"获取总页数: {first_page_url}")
        response = requests.get(first_page_url, headers=REQUEST_HEADERS)
        
        # 动态检测编码
        if response.encoding == 'ISO-8859-1':
            for encoding in ['gbk', 'gb2312', 'utf-8']:
                try:
                    response.encoding = encoding
                    soup = BeautifulSoup(response.text, 'html.parser')
                    if '水稻' in soup.text:
                        print(f"使用编码: {encoding}")
                        break
                except:
                    continue
        
        if response.status_code != 200:
            print(f"请求失败，状态码: {response.status_code}")
            return 1
            
        soup = BeautifulSoup(response.text, 'html.parser')
        
        # 优化页码提取逻辑
        total_pages = 1
        
        # 1. 尝试查找末页链接
        last_page_link = soup.find('a', attrs={"title": "跳至末页"})
        if not last_page_link:
            last_page_link = soup.find('a', string='>>')
        
        if last_page_link:
            href = last_page_link.get('href', '')
            if href:
                match = re.search(r'_(\d+)\.htm$', href)
                if match:
                    total_pages = int(match.group(1))
                    print(f"从末页链接提取总页数: {total_pages}")
        
        # 2. 如果未找到，尝试从分页文本中提取
        if total_pages == 1:
            pagination = soup.find('div', align='center')
            if pagination:
                # 查找类似 "共122页" 的文本
                page_text = pagination.get_text()
                match = re.search(r'共(\d+)页', page_text)
                if match:
                    total_pages = int(match.group(1))
                    print(f"从分页文本提取总页数: {total_pages}")
        
        # 3. 如果还是未找到，尝试从分页链接中推断
        if total_pages == 1:
            print("尝试从分页元素提取最大页码")
            page_links = soup.select('a[href*="_"]')
            max_page = 1
            for link in page_links:
                href = link.get('href', '')
                if href:
                    match = re.search(r'_(\d+)\.htm$', href)
                    if match:
                        page_num = int(match.group(1))
                        if page_num > max_page:
                            max_page = page_num
            total_pages = max_page
            print(f"推断最大页码为: {total_pages}")
        
        return total_pages
    
    except Exception as e:
        print(f"获取 {province_code} 总页数失败: {e}")
        return 1

def scrape_page(province_code, page):
    """爬取单页数据 - 优化序号列提取"""
    headers = []
    data = []
    
    try:
        page_url = f"{base_url}identified/{province_code}_{page}.htm"
        print(f"正在爬取: {page_url}")
        response = requests.get(page_url, headers=REQUEST_HEADERS)
        
        # 动态检测编码
        if response.encoding == 'ISO-8859-1':
            # 尝试常见中文编码
            for encoding in ['gbk', 'gb2312', 'utf-8']:
                try:
                    response.encoding = encoding
                    soup = BeautifulSoup(response.text, 'html.parser')
                    # 检查是否有中文内容
                    if '水稻' in soup.text:
                        print(f"使用编码: {encoding}")
                        break
                except:
                    continue
        
        soup = BeautifulSoup(response.text, 'html.parser')
        
        # 优化表格定位 - 更通用的表格识别方式
        table = None
        
        # 1. 通过特定样式定位
        table = soup.find('table', style=re.compile(r'font-size:13;'))
        
        # 2. 通过特定宽度定位
        if not table:
            table = soup.find('table', width='1200')
        
        # 3. 通过表格内容定位
        if not table:
            all_tables = soup.find_all('table')
            for t in all_tables:
                table_text = t.get_text(strip=True)
                if '序号' in table_text and '品种名称' in table_text:
                    table = t
                    break
        
        if not table:
            print("未找到目标表格")
            return headers, data
        
        # 打印表格HTML片段
        table_html = str(table)[:500]  # 只打印前500个字符
        print(f"表格HTML片段: {table_html}...")
        
        # 优化表头提取 - 确保包含序号列
        # 查找所有可能包含表头的行
        header_rows = []
        for row in table.find_all('tr'):
            # 检查行是否包含表头关键词
            row_text = row.get_text(strip=True)
            if '序号' in row_text and '品种名称' in row_text:
                header_rows.append(row)
        
        # 如果没有找到明确的表头行，使用前两行作为候选
        if not header_rows:
            header_rows = table.find_all('tr', limit=2)
        
        # 遍历候选行，选择最可能是表头的行
        for row in header_rows:
            header_cells = []
            # 收集所有单元格（包括th和td）
            for cell in row.find_all(['th', 'td']):
                # 提取文本并清理
                cell_text = cell.get_text(strip=True).replace('\n', ' ').replace('\t', ' ').replace('  ', ' ')
                if cell_text:
                    header_cells.append(cell_text)
            
            # 检查是否包含序号列
            if header_cells and '序号' in header_cells[0]:
                headers = header_cells
                print(f"找到有效表头: {headers}")
                # 记录表头行的位置
                header_row_index = header_rows.index(row)
                break
        
        # 如果仍未找到表头，使用第一行
        if not headers and header_rows:
            header_cells = []
            for cell in header_rows[0].find_all(['th', 'td']):
                cell_text = cell.get_text(strip=True).replace('\n', ' ').replace('\t', ' ').replace('  ', ' ')
                if cell_text:
                    header_cells.append(cell_text)
            headers = header_cells
            print(f"使用第一行作为表头: {headers}")
            header_row_index = 0
        
        # 提取数据行 - 优化数据提取逻辑
        all_rows = table.find_all('tr')
        data_rows = all_rows[header_row_index + 1:] if 'header_row_index' in locals() else all_rows
        
        for row in data_rows:
            row_data = []
            cells = row.find_all(['td', 'th'])
            
            # 跳过空行
            if not cells:
                continue
                
            for cell in cells:
                # 优化文本提取 - 处理多种情况
                cell_text = cell.get_text(strip=True)
                
                # 处理特殊空白字符
                if not cell_text or cell_text in ['\xa0', '&nbsp;']:
                    cell_text = ''
                
                # 清理多余空格
                cell_text = re.sub(r'\s+', ' ', cell_text).strip()
                
                row_data.append(cell_text)
            
            # 确保行数据与表头列数一致
            if row_data:  # 跳过空行
                if len(row_data) != len(headers):
                    # 尝试修复列数不一致的问题
                    if len(row_data) < len(headers):
                        # 补充缺失的列
                        row_data += [''] * (len(headers) - len(row_data))
                    else:
                        # 截断多余的列
                        row_data = row_data[:len(headers)]
                
                # 确保序号列有值
                if headers and len(row_data) > 0 and not row_data[0].strip():
                    # 尝试从其他位置获取序号
                    # 有时序号在第一个单元格的<b>标签中
                    first_cell = cells[0]
                    b_tag = first_cell.find('b')
                    if b_tag:
                        row_data[0] = b_tag.get_text(strip=True)
                
                data.append(row_data)
        
        print(f"获取到 {len(data)} 条记录")
        return headers, data
    except Exception as e:
        print(f"爬取 {province_code} 第 {page} 页失败: {e}")
        traceback.print_exc()
        return headers, data

def scrape_province(province_name, province_code):
    """爬取单个省份的数据"""
    total_pages = get_total_pages(province_code)
    # 限制最大页数为130
    actual_pages = min(total_pages, 130) if total_pages > 0 else 1
    
    print(f"\n开始爬取 {province_name} 数据，共 {actual_pages}/{total_pages} 页...")
    
    all_data = []
    table_headers = []
    
    for page in range(1, actual_pages + 1):
        print(f"\n{'='*30}")
        print(f"处理 {province_name} 第 {page}/{actual_pages} 页")
        print(f"{'='*30}")
        
        headers, page_data = scrape_page(province_code, page)
        
        # 如果是第一页且获取到了表头，保存表头
        if page == 1 and headers:
            table_headers = headers
            print(f"表头: {table_headers}")
        
        # 在每行数据末尾添加省份名称
        for row in page_data:
            row.append(province_name)  # 添加省份列
        
        if page_data:
            all_data.extend(page_data)
            print(f"已爬取第 {page}/{actual_pages} 页，获取 {len(page_data)} 条记录")
            
            # 打印前3条数据
            print("前3条数据样例:")
            for i, row in enumerate(page_data[:3]):
                print(f"{i+1}. {row}")
        else:
            print(f"第 {page} 页无数据")
        
        # 避免请求过快，随机等待1-3秒
        sleep_time = 1 + 2 * random.random()
        print(f"等待 {sleep_time:.2f} 秒后继续...")
        time.sleep(sleep_time)
    
    if all_data:
        # 在表头中添加"省份"列
        if table_headers:
            table_headers.append("省份")
        else:
            # 如果没有表头，创建默认表头
            num_columns = len(all_data[0]) if all_data else 0
            table_headers = [f"列{i+1}" for i in range(num_columns - 1)] + ["省份"]
            print(f"生成默认表头: {table_headers}")
        
        # 保存为CSV文件
        filename = f"rice_data/{province_name.replace('/', '_')}水稻数据.csv"
        with open(filename, 'w', newline='', encoding='utf-8-sig') as f:
            writer = csv.writer(f)
            # 使用添加了省份列的表头
            writer.writerow(table_headers)
            writer.writerows(all_data)
        print(f"已保存 {len(all_data)} 条数据到 {filename}")
        return len(all_data)
    else:
        print(f"{province_name} 未获取到数据")
        return 0

def main():
    """主函数"""
    print("=" * 50)
    print("国家水稻数据中心数据采集程序")
    print("=" * 50)
    
    # 获取所有省份代码
    provinces = get_province_codes()
    if not provinces:
        print("无法获取省份列表，程序退出")
        return
    
    total_records = 0
    processed_provinces = 0
    total_provinces = len(provinces)
    
    # 爬取所有省份
    for province_name, province_code in provinces.items():
        processed_provinces += 1
        print(f"\n{'#' * 60}")
        print(f"开始处理: {province_name} ({processed_provinces}/{total_provinces})")
        print(f"{'#' * 60}")
        
        try:
            records = scrape_province(province_name, province_code)
            total_records += records
            print(f"已完成 {province_name} 的数据采集，获取 {records} 条记录")
        except Exception as e:
            print(f"处理 {province_name} 时出错: {e}")
            traceback.print_exc()
        
        # 每完成一个省份，等待稍长时间
        sleep_time = 3 + 2 * random.random()
        print(f"等待 {sleep_time:.2f} 秒后处理下一个省份...")
        time.sleep(sleep_time)
    
    print("\n" + "=" * 50)
    print(f"数据采集完成！共获取 {total_records} 条记录")
    print(f"处理了 {processed_provinces} 个省份")
    print("数据保存在 rice_data 文件夹中")
    print("=" * 50)

if __name__ == "__main__":
    main()
# Out:
# ==================================================
# 国家水稻数据中心数据采集程序
# ==================================================
# 正在获取省份列表...
# 使用编码: utf-8
# 找到省份: 农业部 (nation)
# 找到省份: 浙江 (vejd)
# 找到省份: 福建 (fujm)
# 找到省份: 江西 (jdxi)
# 找到省份: 江　苏 (jdsu)
# 找到省份: 安徽 (anhv)
# 找到省份: 上海 (uhhl)
# 找到省份: 山东 (ujds)
# 找到省份: 黑龙江 (hlj)
# 找到省份: 吉林 (jxln)
# 找到省份: 辽宁 (lcny)
# 找到省份: 河北 (hebz)
# 找到省份: 内蒙古 (nmg)
# 找到省份: 山西 (ujxi)
# 找到省份: 天津 (tmjn)
# 找到省份: 北京 (bzjy)
# 找到省份: 陕　西 (sjxi)
# 找到省份: 甘肃 (gjsu)
# 找到省份: 宁夏 (nyxw)
# 找到省份: 新疆 (xnjd)
# 找到省份: 湖　南 (hunj)
# 找到省份: 河南 (henj)
# 找到省份: 湖北 (hubz)
# 找到省份: 广　东 (gdds)
# 找到省份: 广西 (gdxi)
# 找到省份: 海南 (hlnj)
# 找到省份: 四　川 (siir)
# 找到省份: 云南 (ypnj)
# 找到省份:  (vejd)
# 找到省份: 贵州 (gvvb)
# 找到省份: 重庆 (isqy)
# 共找到 31 个省份/部门
#
# ############################################################
# 开始处理: 农业部 (1/31)
# ############################################################
# 获取总页数: https://www.ricedata.cn/variety/identified/nation_1.htm
# 使用编码: gbk
# 从末页链接提取总页数: 122
#
# 开始爬取 农业部 数据，共 122/122 页...
#
# ==============================
# 处理 农业部 第 1/122 页
# ==============================
# 正在爬取: https://www.ricedata.cn/variety/identified/nation_1.htm
# 使用编码: gbk
# 表格HTML片段: <table cellpadding="2" cellspacing="0" style="font-size:13; font-family:Times New Roman; border-top:solid black 2px; border-bottom:solid black 2px" width="1200"><tr align="left"><td height="30" width="50"><b>序号</b></td><td height="30" width="120"><b>品种名称</b></td><td><b>亲本来源（"×"前为母本）</b></td><td width="150"><b>类型</b></td><td><b>原产地/选育单位</b></td><td><b>审定编号</b></td></tr><caption style="text-align:right; font-size:13px; padding-top:15px;color: red"><b>农业部历年审定品种 4268 个：<a href="nation_1.htm" style="...
# 找到有效表头: ['序号', '品种名称', '亲本来源（"×"前为母本）', '类型', '原产地/选育单位', '审定编号']
# 获取到 35 条记录
# 表头: ['序号', '品种名称', '亲本来源（"×"前为母本）', '类型', '原产地/选育单位', '审定编号']
# 已爬取第 1/122 页，获取 35 条记录
# 前3条数据样例:
# 1. ['1', '中科发早粳23', '中科804×吉粳88//嘉禾212/嘉花1号', '粳型常规稻', '中国科学院遗传与发育生物学研究所等', '国审稻20244019', '农业部']
# 2. ['2', '中科发早粳1号', '中科发6号×龙稻18/南方长粒粳//吉粳88', '粳型常规稻', '中国科学院遗传与发育生物学研究所', '国审稻20244018', '农业部']
# 3. ['3', '韶香100', 'R18-3×华占', '籼型常规稻', '湖南杂交水稻研究中心', '国审稻20244017', '农业部']
# 等待 2.07 秒后继续...
#
# ==============================
# 处理 农业部 第 2/122 页
# ==============================
# 正在爬取: https://www.ricedata.cn/variety/identified/nation_2.htm
# 使用编码: gbk
# 表格HTML片段: <table cellpadding="2" cellspacing="0" style="font-size:13; font-family:Times New Roman; border-top:solid black 2px; border-bottom:solid black 2px" width="1200"><tr align="left"><td height="30" width="50"><b>序号</b></td><td height="30" width="120"><b>品种名称</b></td><td><b>亲本来源（"×"前为母本）</b></td><td width="150"><b>类型</b></td><td><b>原产地/选育单位</b></td><td><b>审定编号</b></td></tr><caption style="text-align:right; font-size:13px; padding-top:15px;color: red"><b>农业部历年审定品种 4268 个：<a href="nation_1.htm" style="...
# 找到有效表头: ['序号', '品种名称', '亲本来源（"×"前为母本）', '类型', '原产地/选育单位', '审定编号']
# 获取到 35 条记录
# 已爬取第 2/122 页，获取 35 条记录
# 前3条数据样例:
# 1. ['36', '8两优庐香', '扬28S×庐香丝苗', '籼型两系杂交稻', '安徽荃银超大种业有限公司', '国审稻20243227', '农业部']
# 2. ['37', '九优荃莹丝苗', '荃9311A×荃莹丝苗', '籼型三系杂交稻', '湖北荃银高科种业有限公司等', '国审稻20243226', '农业部']
# 3. ['38', '中佳早88', '159410T-2/11G-75×辐805', '籼型常规稻', '中国水稻研究所等', '国审稻20243225', '农业部']
# 等待 1.96 秒后继续...
#
# ==============================
# 处理 农业部 第 3/122 页
# ==============================
# 正在爬取: https://www.ricedata.cn/variety/identified/nation_3.htm
# 使用编码: gbk
# 表格HTML片段: <table cellpadding="2" cellspacing="0" style="font-size:13; font-family:Times New Roman; border-top:solid black 2px; border-bottom:solid black 2px" width="1200"><tr align="left"><td height="30" width="50"><b>序号</b></td><td height="30" width="120"><b>品种名称</b></td><td><b>亲本来源（"×"前为母本）</b></td><td width="150"><b>类型</b></td><td><b>原产地/选育单位</b></td><td><b>审定编号</b></td></tr><caption style="text-align:right; font-size:13px; padding-top:15px;color: red"><b>农业部历年审定品种 4268 个：<a href="nation_1.htm" style="...
# 找到有效表头: ['序号', '品种名称', '亲本来源（"×"前为母本）', '类型', '原产地/选育单位', '审定编号']
# 获取到 35 条记录
# 已爬取第 3/122 页，获取 35 条记录
# 前3条数据样例:
# 1. ['71', '嘉优8107', '嘉89A×嘉恢8107', '粳型三系杂交稻', '浙江禾天下种业股份有限公司等', '国审稻20243192', '农业部']
# 2. ['72', '光明优2021', '15-75A×CR16-257', '粳型三系杂交稻', '中垦种业股份有限公司', '国审稻20243191', '农业部']
# 3. ['73', '明祥优6559', '明祥A×明恢6559', '籼型三系杂交稻', '福建六三种业有限责任公司等', '国审稻20243190', '农业部']
# 等待 2.39 秒后继续...
#
# ==============================
# 处理 农业部 第 4/122 页
# ==============================
# 正在爬取: https://www.ricedata.cn/variety/identified/nation_4.htm
# 使用编码: gbk
# 表格HTML片段: <table cellpadding="2" cellspacing="0" style="font-size:13; font-family:Times New Roman; border-top:solid black 2px; border-bottom:solid black 2px" width="1200"><tr align="left"><td height="30" width="50"><b>序号</b></td><td height="30" width="120"><b>品种名称</b></td><td><b>亲本来源（"×"前为母本）</b></td><td width="150"><b>类型</b></td><td><b>原产地/选育单位</b></td><td><b>审定编号</b></td></tr><caption style="text-align:right; font-size:13px; padding-top:15px;color: red"><b>农业部历年审定品种 4268 个：<a href="nation_1.htm" style="...
# 找到有效表头: ['序号', '品种名称', '亲本来源（"×"前为母本）', '类型', '原产地/选育单位', '审定编号']
# 获取到 35 条记录
# 已爬取第 4/122 页，获取 35 条记录
# 前3条数据样例:
# 1. ['106', '振优619', '振295A×MR619', '籼型三系杂交稻', '北京金色农华种业科技股份有限公司等', '国审稻20243157', '农业部']
# 2. ['107', '裕香丝苗', '五山丝苗×象牙香占', '籼型常规稻', '安徽喜多收种业科技有限公司', '国审稻20243156', '农业部']
# 3. ['108', '郢两优118', '郢216S×R1188', '籼型两系杂交稻', '湖北荃银高科种业有限公司', '国审稻20243155', '农业部']
# 等待 1.75 秒后继续...
#
# ==============================
# 处理 农业部 第 5/122 页
# ==============================
# 正在爬取: https://www.ricedata.cn/variety/identified/nation_5.htm
# 使用编码: gbk
# 表格HTML片段: <table cellpadding="2" cellspacing="0" style="font-size:13; font-family:Times New Roman; border-top:solid black 2px; border-bottom:solid black 2px" width="1200"><tr align="left"><td height="30" width="50"><b>序号</b></td><td height="30" width="120"><b>品种名称</b></td><td><b>亲本来源（"×"前为母本）</b></td><td width="150"><b>类型</b></td><td><b>原产地/选育单位</b></td><td><b>审定编号</b></td></tr><caption style="text-align:right; font-size:13px; padding-top:15px;color: red"><b>农业部历年审定品种 4268 个：<a href="nation_1.htm" style="...
# 找到有效表头: ['序号', '品种名称', '亲本来源（"×"前为母本）', '类型', '原产地/选育单位', '审定编号']
# 获取到 35 条记录
# 已爬取第 5/122 页，获取 35 条记录
# 前3条数据样例:
# 1. ['141', '远两优科占', '远02S×科占', '籼型两系杂交稻', '安徽科远现代农业科技有限公司', '国审稻20243122', '农业部']
# 2. ['142', '缘两优晶丝', '缘88S×晶丝', '籼型两系杂交稻', '安徽兆和种业有限公司等', '国审稻20243121', '农业部']
# 3. ['143', '原两优粤香丝', 'V18S×R903', '籼型两系杂交稻', '湖南兆和种业有限公司', '国审稻20243120', '农业部']
# 等待 2.15 秒后继续...
#
# ==============================
# 处理 农业部 第 6/122 页
# ==============================
# 正在爬取: https://www.ricedata.cn/variety/identified/nation_6.htm
# 使用编码: gbk
# 表格HTML片段: <table cellpadding="2" cellspacing="0" style="font-size:13; font-family:Times New Roman; border-top:solid black 2px; border-bottom:solid black 2px" width="1200"><tr align="left"><td height="30" width="50"><b>序号</b></td><td height="30" width="120"><b>品种名称</b></td><td><b>亲本来源（"×"前为母本）</b></td><td width="150"><b>类型</b></td><td><b>原产地/选育单位</b></td><td><b>审定编号</b></td></tr><caption style="text-align:right; font-size:13px; padding-top:15px;color: red"><b>农业部历年审定品种 4268 个：<a href="nation_1.htm" style="...
# 找到有效表头: ['序号', '品种名称', '亲本来源（"×"前为母本）', '类型', '原产地/选育单位', '审定编号']
# 获取到 35 条记录
# 已爬取第 6/122 页，获取 35 条记录
# 前3条数据样例:
# 1. ['176', '荃两优985', '荃211S×YR985', '籼型两系杂交稻', '广东荃银种业科技有限公司等', '国审稻20243087', '农业部']
# 2. ['177', '荃广优532', '荃广A×YH532', '籼型三系杂交稻', '安徽荃银高科种业股份有限公司', '国审稻20243086', '农业部']
# 3. ['178', '祺两优5306', '祺S×R5306', '籼型两系杂交稻', '湖南兴隆种业有限公司', '国审稻20243085', '农业部']
# 等待 1.97 秒后继续...
#
# ==============================
# 处理 农业部 第 7/122 页
# ==============================
# 正在爬取: https://www.ricedata.cn/variety/identified/nation_7.htm
# 使用编码: gbk
# 表格HTML片段: <table cellpadding="2" cellspacing="0" style="font-size:13; font-family:Times New Roman; border-top:solid black 2px; border-bottom:solid black 2px" width="1200"><tr align="left"><td height="30" width="50"><b>序号</b></td><td height="30" width="120"><b>品种名称</b></td><td><b>亲本来源（"×"前为母本）</b></td><td width="150"><b>类型</b></td><td><b>原产地/选育单位</b></td><td><b>审定编号</b></td></tr><caption style="text-align:right; font-size:13px; padding-top:15px;color: red"><b>农业部历年审定品种 4268 个：<a href="nation_1.htm" style="...
# 找到有效表头: ['序号', '品种名称', '亲本来源（"×"前为母本）', '类型', '原产地/选育单位', '审定编号']
# 获取到 35 条记录
# 已爬取第 7/122 页，获取 35 条记录
# 前3条数据样例:
# 1. ['211', '多两优106', '喜6386S×喜恢106', '籼型两系杂交稻', '安徽喜多收种业科技有限公司', '国审稻20243052', '农业部']
# 2. ['212', '稻两优二九', '华稻379S×R2094', '籼型两系杂交稻', '福建东南天力种业有限公司', '国审稻20243051', '农业部']
# 3. ['213', '春9两优851', '春199S×YR851', '籼型两系杂交稻', '中国农业科学院深圳农业基因组研究所等', '国审稻20243050', '农业部']
# 等待 2.54 秒后继续...
#
# ==============================
# 处理 农业部 第 8/122 页
# ==============================
# 正在爬取: https://www.ricedata.cn/variety/identified/nation_8.htm
# 使用编码: gbk
# 表格HTML片段: <table cellpadding="2" cellspacing="0" style="font-size:13; font-family:Times New Roman; border-top:solid black 2px; border-bottom:solid black 2px" width="1200"><tr align="left"><td height="30" width="50"><b>序号</b></td><td height="30" width="120"><b>品种名称</b></td><td><b>亲本来源（"×"前为母本）</b></td><td width="150"><b>类型</b></td><td><b>原产地/选育单位</b></td><td><b>审定编号</b></td></tr><caption style="text-align:right; font-size:13px; padding-top:15px;color: red"><b>农业部历年审定品种 4268 个：<a href="nation_1.htm" style="...
# 找到有效表头: ['序号', '品种名称', '亲本来源（"×"前为母本）', '类型', '原产地/选育单位', '审定编号']
# 获取到 35 条记录
# 已爬取第 8/122 页，获取 35 条记录
# 前3条数据样例:
# 1. ['246', '华两优袁恢丝苗', '华兴166S×袁恢丝苗', '籼型两系杂交稻', '安徽袁粮种业科学研究院等', '国审稻20243017', '农业部']
# 2. ['247', '华谷优闽香丝苗', '华谷292A×闽香丝苗', '籼型三系杂交稻', '绵阳致道农业科技有限公司等', '国审稻20243016', '农业部']
# 3. ['248', '旱优56', '沪旱5A×旱恢56', '籼型三系杂交稻', '上海市农业生物基因中心等', '国审稻20243015', '农业部']
# 等待 2.24 秒后继续...
#
# ==============================
# 处理 农业部 第 9/122 页
# ==============================
# 正在爬取: https://www.ricedata.cn/variety/identified/nation_9.htm
# 使用编码: gbk
# 表格HTML片段: <table cellpadding="2" cellspacing="0" style="font-size:13; font-family:Times New Roman; border-top:solid black 2px; border-bottom:solid black 2px" width="1200"><tr align="left"><td height="30" width="50"><b>序号</b></td><td height="30" width="120"><b>品种名称</b></td><td><b>亲本来源（"×"前为母本）</b></td><td width="150"><b>类型</b></td><td><b>原产地/选育单位</b></td><td><b>审定编号</b></td></tr><caption style="text-align:right; font-size:13px; padding-top:15px;color: red"><b>农业部历年审定品种 4268 个：<a href="nation_1.htm" style="...
# 找到有效表头: ['序号', '品种名称', '亲本来源（"×"前为母本）', '类型', '原产地/选育单位', '审定编号']
# 获取到 35 条记录
# 已爬取第 9/122 页，获取 35 条记录
# 前3条数据样例:
# 1. ['281', '桃湘优188', '桃湘A×R188', '籼型三系杂交稻', '湖南桃花源农业科技股份有限公司', '国审稻20242086', '农业部']
# 2. ['282', '荃优香66', '荃9311A×荃恢15号', '籼型三系杂交稻', '安徽荃银高科种业股份有限公司', '国审稻20242085', '农业部']
# 3. ['283', '荃优386', '荃9311A×YR086', '籼型三系杂交稻', '安徽荃银高科种业股份有限公司', '国审稻20242084', '农业部']
# 等待 2.25 秒后继续...
#
# ==============================
# 处理 农业部 第 10/122 页
# ==============================
# 正在爬取: https://www.ricedata.cn/variety/identified/nation_10.htm
# 使用编码: gbk
# 表格HTML片段: <table cellpadding="2" cellspacing="0" style="font-size:13; font-family:Times New Roman; border-top:solid black 2px; border-bottom:solid black 2px" width="1200"><tr align="left"><td height="30" width="50"><b>序号</b></td><td height="30" width="120"><b>品种名称</b></td><td><b>亲本来源（"×"前为母本）</b></td><td width="150"><b>类型</b></td><td><b>原产地/选育单位</b></td><td><b>审定编号</b></td></tr><caption style="text-align:right; font-size:13px; padding-top:15px;color: red"><b>农业部历年审定品种 4268 个：<a href="nation_1.htm" style="...
# 找到有效表头: ['序号', '品种名称', '亲本来源（"×"前为母本）', '类型', '原产地/选育单位', '审定编号']
# 获取到 35 条记录
# 已爬取第 10/122 页，获取 35 条记录
# 前3条数据样例:
# 1. ['316', '振两优泰丝', '振湘S×泰丝', '籼型两系杂交稻', '袁隆平农业高科技股份有限公司等', '国审稻20242051', '农业部']
# 2. ['317', '银两优606', '银312S×YR1606', '籼型两系杂交稻', '安徽荃银高科种业股份有限公司', '国审稻20242050', '农业部']
# 3. ['318', '扬泰优2208', '扬泰A×华恢2208', '籼型三系杂交稻', '袁隆平农业高科技股份有限公司等', '国审稻20242049', '农业部']
# 等待 1.55 秒后继续...
#
# ==============================
# 处理 农业部 第 11/122 页
# ==============================
# 正在爬取: https://www.ricedata.cn/variety/identified/nation_11.htm
# 使用编码: gbk
# 表格HTML片段: <table cellpadding="2" cellspacing="0" style="font-size:13; font-family:Times New Roman; border-top:solid black 2px; border-bottom:solid black 2px" width="1200"><tr align="left"><td height="30" width="50"><b>序号</b></td><td height="30" width="120"><b>品种名称</b></td><td><b>亲本来源（"×"前为母本）</b></td><td width="150"><b>类型</b></td><td><b>原产地/选育单位</b></td><td><b>审定编号</b></td></tr><caption style="text-align:right; font-size:13px; padding-top:15px;color: red"><b>农业部历年审定品种 4268 个：<a href="nation_1.htm" style="...
# 找到有效表头: ['序号', '品种名称', '亲本来源（"×"前为母本）', '类型', '原产地/选育单位', '审定编号']
# 获取到 35 条记录
# 已爬取第 11/122 页，获取 35 条记录
# 前3条数据样例:
# 1. ['351', '安两优洁田2023', '安1110S×洁田2023', '籼型两系杂交稻', '合肥丰乐种业股份有限公司', '国审稻20242016', '农业部']
# 2. ['352', '安两优676', '安1110S×R676', '籼型两系杂交稻', '合肥丰乐种业股份有限公司', '国审稻20242015', '农业部']
# 3. ['353', '宜香优晟禾', '宜香1A×晟禾', '籼型三系杂交稻', '中国种子集团有限公司等', '国审稻20242014', '农业部']
# 等待 2.91 秒后继续...
#
# ==============================
# 处理 农业部 第 12/122 页
# ==============================
# 正在爬取: https://www.ricedata.cn/variety/identified/nation_12.htm
# 使用编码: gbk
# 表格HTML片段: <table cellpadding="2" cellspacing="0" style="font-size:13; font-family:Times New Roman; border-top:solid black 2px; border-bottom:solid black 2px" width="1200"><tr align="left"><td height="30" width="50"><b>序号</b></td><td height="30" width="120"><b>品种名称</b></td><td><b>亲本来源（"×"前为母本）</b></td><td width="150"><b>类型</b></td><td><b>原产地/选育单位</b></td><td><b>审定编号</b></td></tr><caption style="text-align:right; font-size:13px; padding-top:15px;color: red"><b>农业部历年审定品种 4268 个：<a href="nation_1.htm" style="...
# 找到有效表头: ['序号', '品种名称', '亲本来源（"×"前为母本）', '类型', '原产地/选育单位', '审定编号']
# 获取到 35 条记录
# 已爬取第 12/122 页，获取 35 条记录
# 前3条数据样例:
# 1. ['386', '华两优2822', '华1228S×HR22', '籼型两系杂交稻', '华中农业大学', '国审稻20241020', '农业部']
# 2. ['387', '银两优392', '银312S×YR392', '籼型两系杂交稻', '安徽荃银高科种业股份有限公司', '国审稻20241019', '农业部']
# 3. ['388', '两优678', '6102S×R178', '籼型两系杂交稻', '安徽省农业科学院水稻研究所', '国审稻20241018', '农业部']
# 等待 2.73 秒后继续...
#
# ==============================
# 处理 农业部 第 13/122 页
# ==============================
# 正在爬取: https://www.ricedata.cn/variety/identified/nation_13.htm
# 使用编码: gbk
# 表格HTML片段: <table cellpadding="2" cellspacing="0" style="font-size:13; font-family:Times New Roman; border-top:solid black 2px; border-bottom:solid black 2px" width="1200"><tr align="left"><td height="30" width="50"><b>序号</b></td><td height="30" width="120"><b>品种名称</b></td><td><b>亲本来源（"×"前为母本）</b></td><td width="150"><b>类型</b></td><td><b>原产地/选育单位</b></td><td><b>审定编号</b></td></tr><caption style="text-align:right; font-size:13px; padding-top:15px;color: red"><b>农业部历年审定品种 4268 个：<a href="nation_1.htm" style="...
# 找到有效表头: ['序号', '品种名称', '亲本来源（"×"前为母本）', '类型', '原产地/选育单位', '审定编号']
# 获取到 35 条记录
# 已爬取第 13/122 页，获取 35 条记录
# 前3条数据样例:
# 1. ['421', '精华122', '精华3号×徐稻9号', '粳型常规稻', '郯城县精华种业有限公司', '国审稻20233263', '农业部']
# 2. ['422', '嘉优中科20-10', '嘉57A×中科嘉恢20-10', '粳型三系杂交稻', '中国科学院遗传与发育生物学研究所等', '国审稻20233262', '农业部']
# 3. ['423', '济润902', '津稻263×金粳818', '粳型常规稻', '山东润农种业科技有限公司', '国审稻20233261', '农业部']
# 等待 1.24 秒后继续...
#
# ==============================
# 处理 农业部 第 14/122 页
# ==============================
# 正在爬取: https://www.ricedata.cn/variety/identified/nation_14.htm
# 使用编码: gbk
# 表格HTML片段: <table cellpadding="2" cellspacing="0" style="font-size:13; font-family:Times New Roman; border-top:solid black 2px; border-bottom:solid black 2px" width="1200"><tr align="left"><td height="30" width="50"><b>序号</b></td><td height="30" width="120"><b>品种名称</b></td><td><b>亲本来源（"×"前为母本）</b></td><td width="150"><b>类型</b></td><td><b>原产地/选育单位</b></td><td><b>审定编号</b></td></tr><caption style="text-align:right; font-size:13px; padding-top:15px;color: red"><b>农业部历年审定品种 4268 个：<a href="nation_1.htm" style="...
# 找到有效表头: ['序号', '品种名称', '亲本来源（"×"前为母本）', '类型', '原产地/选育单位', '审定编号']
# 获取到 35 条记录
# 已爬取第 14/122 页，获取 35 条记录
# 前3条数据样例:
# 1. ['456', '郢两优258', '郢216S×R58', '籼型两系杂交稻', '湖北荃银高科种业有限公司', '国审稻20233228', '农业部']
# 2. ['457', '银两优535', '银312S×YR53213', '籼型两系杂交稻', '安徽荃银种业科技有限公司等', '国审稻20233227', '农业部']
# 3. ['458', '野香优美特占', '野香A×美特占', '籼型三系杂交稻', '江西农业大学农学院', '国审稻20233226', '农业部']
# 等待 1.77 秒后继续...
#
# ==============================
# 处理 农业部 第 15/122 页
# ==============================
# 正在爬取: https://www.ricedata.cn/variety/identified/nation_15.htm
# 使用编码: gbk
# 表格HTML片段: <table cellpadding="2" cellspacing="0" style="font-size:13; font-family:Times New Roman; border-top:solid black 2px; border-bottom:solid black 2px" width="1200"><tr align="left"><td height="30" width="50"><b>序号</b></td><td height="30" width="120"><b>品种名称</b></td><td><b>亲本来源（"×"前为母本）</b></td><td width="150"><b>类型</b></td><td><b>原产地/选育单位</b></td><td><b>审定编号</b></td></tr><caption style="text-align:right; font-size:13px; padding-top:15px;color: red"><b>农业部历年审定品种 4268 个：<a href="nation_1.htm" style="...
# 找到有效表头: ['序号', '品种名称', '亲本来源（"×"前为母本）', '类型', '原产地/选育单位', '审定编号']
# 获取到 35 条记录
# 已爬取第 15/122 页，获取 35 条记录
# 前3条数据样例:
# 1. ['491', '亿香晶占', '黄华占×粤禾丝苗', '籼型常规稻', '安徽日辉生物科技有限公司', '国审稻20233193', '农业部']
# 2. ['492', '欣两优晚2002', '欣9249S×欣恢2002', '籼型两系杂交稻', '安徽荃银欣隆种业有限公司', '国审稻20233192', '农业部']
# 3. ['493', '欣两优四号', '欣9153S×欣恢二号', '籼型两系杂交稻', '安徽荃银欣隆种业有限公司', '国审稻20233191', '农业部']
# 等待 1.43 秒后继续...
#
# ==============================
# 处理 农业部 第 16/122 页
# ==============================
# 正在爬取: https://www.ricedata.cn/variety/identified/nation_16.htm
# 使用编码: gbk
# 表格HTML片段: <table cellpadding="2" cellspacing="0" style="font-size:13; font-family:Times New Roman; border-top:solid black 2px; border-bottom:solid black 2px" width="1200"><tr align="left"><td height="30" width="50"><b>序号</b></td><td height="30" width="120"><b>品种名称</b></td><td><b>亲本来源（"×"前为母本）</b></td><td width="150"><b>类型</b></td><td><b>原产地/选育单位</b></td><td><b>审定编号</b></td></tr><caption style="text-align:right; font-size:13px; padding-top:15px;color: red"><b>农业部历年审定品种 4268 个：<a href="nation_1.htm" style="...
# 找到有效表头: ['序号', '品种名称', '亲本来源（"×"前为母本）', '类型', '原产地/选育单位', '审定编号']
# 获取到 35 条记录
# 已爬取第 16/122 页，获取 35 条记录
# 前3条数据样例:
# 1. ['526', '昱两优126', '昱辰S×ZR126', '籼型两系杂交稻', '安徽金培因科技有限公司等', '国审稻20233158', '农业部']
# 2. ['527', '怡两优粤禾丝苗', '怡8S×粤禾丝苗', '籼型两系杂交稻', '江西金信种业有限公司等', '国审稻20233157', '农业部']
# 3. ['528', '夷优811', '夷A×兴恢811', '籼型三系杂交稻', '武夷山科力兴种业有限公司', '国审稻20233156', '农业部']
# 等待 2.92 秒后继续...
#
# ==============================
# 处理 农业部 第 17/122 页
# ==============================
# 正在爬取: https://www.ricedata.cn/variety/identified/nation_17.htm
# 使用编码: gbk
# 表格HTML片段: <table cellpadding="2" cellspacing="0" style="font-size:13; font-family:Times New Roman; border-top:solid black 2px; border-bottom:solid black 2px" width="1200"><tr align="left"><td height="30" width="50"><b>序号</b></td><td height="30" width="120"><b>品种名称</b></td><td><b>亲本来源（"×"前为母本）</b></td><td width="150"><b>类型</b></td><td><b>原产地/选育单位</b></td><td><b>审定编号</b></td></tr><caption style="text-align:right; font-size:13px; padding-top:15px;color: red"><b>农业部历年审定品种 4268 个：<a href="nation_1.htm" style="...
# 找到有效表头: ['序号', '品种名称', '亲本来源（"×"前为母本）', '类型', '原产地/选育单位', '审定编号']
# 获取到 35 条记录
# 已爬取第 17/122 页，获取 35 条记录
# 前3条数据样例:
# 1. ['561', '明太优韵农丝苗', '明太A×韵农丝苗', '籼型三系杂交稻', '安徽华韵生物科技有限公司', '国审稻20233123', '农业部']
# 2. ['562', '明太优6363', '明太A×茂烣6363', '籼型三系杂交稻', '三明市茂丰农业科技开发有限公司等', '国审稻20233122', '农业部']
# 3. ['563', '明两优916', '明8S×明恢916', '籼型两系杂交稻', '福建旺穗种业有限公司等', '国审稻20233121', '农业部']
# 等待 2.44 秒后继续...
#
# ==============================
# 处理 农业部 第 18/122 页
# ==============================
# 正在爬取: https://www.ricedata.cn/variety/identified/nation_18.htm
# 使用编码: gbk
# 表格HTML片段: <table cellpadding="2" cellspacing="0" style="font-size:13; font-family:Times New Roman; border-top:solid black 2px; border-bottom:solid black 2px" width="1200"><tr align="left"><td height="30" width="50"><b>序号</b></td><td height="30" width="120"><b>品种名称</b></td><td><b>亲本来源（"×"前为母本）</b></td><td width="150"><b>类型</b></td><td><b>原产地/选育单位</b></td><td><b>审定编号</b></td></tr><caption style="text-align:right; font-size:13px; padding-top:15px;color: red"><b>农业部历年审定品种 4268 个：<a href="nation_1.htm" style="...
# 找到有效表头: ['序号', '品种名称', '亲本来源（"×"前为母本）', '类型', '原产地/选育单位', '审定编号']
# 获取到 35 条记录
# 已爬取第 18/122 页，获取 35 条记录
# 前3条数据样例:
# 1. ['596', '菁两优溢香丝苗', '菁31S×溢香丝苗', '籼型两系杂交稻', '湖南恒大种业高科技有限公司', '国审稻20233088', '农业部']
# 2. ['597', '津两优261', '津S×16T-261', '籼型两系杂交稻', '湖南金健种业科技有限公司等', '国审稻20233087', '农业部']
# 3. ['598', '嘉优8201', '嘉74A×嘉恢8201', '籼型三系杂交稻', '浙江禾天下种业股份有限公司等', '国审稻20233086', '农业部']
# 等待 1.90 秒后继续...
#
# ==============================
# 处理 农业部 第 19/122 页
# ==============================
# 正在爬取: https://www.ricedata.cn/variety/identified/nation_19.htm
# 使用编码: gbk
# 表格HTML片段: <table cellpadding="2" cellspacing="0" style="font-size:13; font-family:Times New Roman; border-top:solid black 2px; border-bottom:solid black 2px" width="1200"><tr align="left"><td height="30" width="50"><b>序号</b></td><td height="30" width="120"><b>品种名称</b></td><td><b>亲本来源（"×"前为母本）</b></td><td width="150"><b>类型</b></td><td><b>原产地/选育单位</b></td><td><b>审定编号</b></td></tr><caption style="text-align:right; font-size:13px; padding-top:15px;color: red"><b>农业部历年审定品种 4268 个：<a href="nation_1.htm" style="...
# 找到有效表头: ['序号', '品种名称', '亲本来源（"×"前为母本）', '类型', '原产地/选育单位', '审定编号']
# 获取到 35 条记录
# 已爬取第 19/122 页，获取 35 条记录
# 前3条数据样例:
# 1. ['631', '缘两优玖香', '缘88S×香恢188', '籼型两系杂交稻', '安徽兆和种业有限公司等', '国审稻20233053', '农业部']
# 2. ['632', '又香优海香', '又香A×海香', '籼型三系杂交稻', '广西兆和种业有限公司等', '国审稻20233052', '农业部']
# 3. ['633', '又香优15香', '又香A×15香', '籼型三系杂交稻', '广西兆和种业有限公司等', '国审稻20233051', '农业部']
# 等待 2.19 秒后继续...
#
# ==============================
# 处理 农业部 第 20/122 页
# ==============================
# 正在爬取: https://www.ricedata.cn/variety/identified/nation_20.htm
# 使用编码: gbk
# 表格HTML片段: <table cellpadding="2" cellspacing="0" style="font-size:13; font-family:Times New Roman; border-top:solid black 2px; border-bottom:solid black 2px" width="1200"><tr align="left"><td height="30" width="50"><b>序号</b></td><td height="30" width="120"><b>品种名称</b></td><td><b>亲本来源（"×"前为母本）</b></td><td width="150"><b>类型</b></td><td><b>原产地/选育单位</b></td><td><b>审定编号</b></td></tr><caption style="text-align:right; font-size:13px; padding-top:15px;color: red"><b>农业部历年审定品种 4268 个：<a href="nation_1.htm" style="...
# 找到有效表头: ['序号', '品种名称', '亲本来源（"×"前为母本）', '类型', '原产地/选育单位', '审定编号']
# 获取到 35 条记录
# 已爬取第 20/122 页，获取 35 条记录
# 前3条数据样例:
# 1. ['666', '萃两优7933', '萃315S×尚恢7933', '籼型两系杂交稻', '四川聚隆汇智农业有限公司等', '国审稻20233018', '农业部']
# 2. ['667', '川优8150', '川608A×泸恢6150', '籼型三系杂交稻', '四川省农业科学院水稻高粱研究所等', '国审稻20233017', '农业部']
# 3. ['668', '10香优龙丝苗', '10香A×龙丝苗', '籼型三系杂交稻', '南宁谷源丰种业有限公司', '国审稻20233016', '农业部']
# 等待 2.62 秒后继续...
#
# ==============================
# 处理 农业部 第 21/122 页
# ==============================
# 正在爬取: https://www.ricedata.cn/variety/identified/nation_21.htm
# 使用编码: gbk
# 表格HTML片段: <table cellpadding="2" cellspacing="0" style="font-size:13; font-family:Times New Roman; border-top:solid black 2px; border-bottom:solid black 2px" width="1200"><tr align="left"><td height="30" width="50"><b>序号</b></td><td height="30" width="120"><b>品种名称</b></td><td><b>亲本来源（"×"前为母本）</b></td><td width="150"><b>类型</b></td><td><b>原产地/选育单位</b></td><td><b>审定编号</b></td></tr><caption style="text-align:right; font-size:13px; padding-top:15px;color: red"><b>农业部历年审定品种 4268 个：<a href="nation_1.htm" style="...
# 找到有效表头: ['序号', '品种名称', '亲本来源（"×"前为母本）', '类型', '原产地/选育单位', '审定编号']
# 获取到 35 条记录
# 已爬取第 21/122 页，获取 35 条记录
# 前3条数据样例:
# 1. ['701', '银两优晶占', '银312S×金晶占', '籼型两系杂交稻', '安徽荃银高科种业股份有限公司等', '国审稻20232072', '农业部']
# 2. ['702', '银两优501', '银312S×YR501', '籼型两系杂交稻', '安徽荃银高科种业股份有限公司等', '国审稻20232071', '农业部']
# 3. ['703', '银两优392', '银312S×YR392', '籼型两系杂交稻', '安徽荃银高科种业股份有限公司', '国审稻20232070', '农业部']
# 等待 2.30 秒后继续...
#
# ==============================
# 处理 农业部 第 22/122 页
# ==============================
# 正在爬取: https://www.ricedata.cn/variety/identified/nation_22.htm
# 使用编码: gbk
# 表格HTML片段: <table cellpadding="2" cellspacing="0" style="font-size:13; font-family:Times New Roman; border-top:solid black 2px; border-bottom:solid black 2px" width="1200"><tr align="left"><td height="30" width="50"><b>序号</b></td><td height="30" width="120"><b>品种名称</b></td><td><b>亲本来源（"×"前为母本）</b></td><td width="150"><b>类型</b></td><td><b>原产地/选育单位</b></td><td><b>审定编号</b></td></tr><caption style="text-align:right; font-size:13px; padding-top:15px;color: red"><b>农业部历年审定品种 4268 个：<a href="nation_1.htm" style="...
# 找到有效表头: ['序号', '品种名称', '亲本来源（"×"前为母本）', '类型', '原产地/选育单位', '审定编号']
# 获取到 35 条记录
# 已爬取第 22/122 页，获取 35 条记录
# 前3条数据样例:
# 1. ['736', '七两优华占', '七s×华占', '籼型两系杂交稻', '合肥丰乐种业股份有限公司等', '国审稻20232037', '农业部']
# 2. ['737', '两优7071', '7011S×R071', '籼型两系杂交稻', '合肥丰乐种业股份有限公司等', '国审稻20232036', '农业部']
# 3. ['738', '晶锋优6285', '晶锋8A×华恢6285', '籼型三系杂交稻', '袁隆平农业高科技股份有限公司等', '国审稻20232035', '农业部']
# 等待 2.88 秒后继续...
#
# ==============================
# 处理 农业部 第 23/122 页
# ==============================
# 正在爬取: https://www.ricedata.cn/variety/identified/nation_23.htm
# 使用编码: gbk
# 表格HTML片段: <table cellpadding="2" cellspacing="0" style="font-size:13; font-family:Times New Roman; border-top:solid black 2px; border-bottom:solid black 2px" width="1200"><tr align="left"><td height="30" width="50"><b>序号</b></td><td height="30" width="120"><b>品种名称</b></td><td><b>亲本来源（"×"前为母本）</b></td><td width="150"><b>类型</b></td><td><b>原产地/选育单位</b></td><td><b>审定编号</b></td></tr><caption style="text-align:right; font-size:13px; padding-top:15px;color: red"><b>农业部历年审定品种 4268 个：<a href="nation_1.htm" style="...
# 找到有效表头: ['序号', '品种名称', '亲本来源（"×"前为母本）', '类型', '原产地/选育单位', '审定编号']
# 获取到 35 条记录
# 已爬取第 23/122 页，获取 35 条记录
# 前3条数据样例:
# 1. ['771', '康两优911', '康58S×创恢911', '籼型两系杂交稻', '湖南袁创超级稻技术有限公司', '国审稻20232002', '农业部']
# 2. ['772', '吨两优丝占', '吨S×创恢丝占', '籼型两系杂交稻', '湖南袁创超级稻技术有限公司', '国审稻20232001', '农业部']
# 3. ['773', '嘉硕优70', '嘉禾212A×硕恢70', '粳型三系杂交稻', '安徽荃银高科种业股份有限公司等', '国审稻20231051', '农业部']
# 等待 2.79 秒后继续...
#
# ==============================
# 处理 农业部 第 24/122 页
# ==============================
# 正在爬取: https://www.ricedata.cn/variety/identified/nation_24.htm
# 使用编码: gbk
# 表格HTML片段: <table cellpadding="2" cellspacing="0" style="font-size:13; font-family:Times New Roman; border-top:solid black 2px; border-bottom:solid black 2px" width="1200"><tr align="left"><td height="30" width="50"><b>序号</b></td><td height="30" width="120"><b>品种名称</b></td><td><b>亲本来源（"×"前为母本）</b></td><td width="150"><b>类型</b></td><td><b>原产地/选育单位</b></td><td><b>审定编号</b></td></tr><caption style="text-align:right; font-size:13px; padding-top:15px;color: red"><b>农业部历年审定品种 4268 个：<a href="nation_1.htm" style="...
# 找到有效表头: ['序号', '品种名称', '亲本来源（"×"前为母本）', '类型', '原产地/选育单位', '审定编号']
# 获取到 35 条记录
# 已爬取第 24/122 页，获取 35 条记录
# 前3条数据样例:
# 1. ['806', '粮两优莉珍', '粮98S×R莉珍', '籼型两系杂交稻', '湖南粮安科技股份有限公司', '国审稻20231018', '农业部']
# 2. ['807', '华两优珍美', '华创S×华创珍美', '籼型两系杂交稻', '湖南粮安科技股份有限公司', '国审稻20231017', '农业部']
# 3. ['808', '花两优36', '花18S×TR36', '籼型两系杂交稻', '安徽桃花源农业科技有限责任公司', '国审稻20231016', '农业部']
# 等待 1.92 秒后继续...
#
# ==============================
# 处理 农业部 第 25/122 页
# ==============================
# 正在爬取: https://www.ricedata.cn/variety/identified/nation_25.htm
# 使用编码: gbk
# 表格HTML片段: <table cellpadding="2" cellspacing="0" style="font-size:13; font-family:Times New Roman; border-top:solid black 2px; border-bottom:solid black 2px" width="1200"><tr align="left"><td height="30" width="50"><b>序号</b></td><td height="30" width="120"><b>品种名称</b></td><td><b>亲本来源（"×"前为母本）</b></td><td width="150"><b>类型</b></td><td><b>原产地/选育单位</b></td><td><b>审定编号</b></td></tr><caption style="text-align:right; font-size:13px; padding-top:15px;color: red"><b>农业部历年审定品种 4268 个：<a href="nation_1.htm" style="...
# 找到有效表头: ['序号', '品种名称', '亲本来源（"×"前为母本）', '类型', '原产地/选育单位', '审定编号']
# 获取到 35 条记录
# 已爬取第 25/122 页，获取 35 条记录
# 前3条数据样例:
# 1. ['841', '桃源香丝苗', '桃丝晶×R188', '籼型常规稻', '湖南桃花源农业科技股份有限公司等', '国审稻20226115', '农业部']
# 2. ['842', '泰谷优618', '泰谷A×荟恢618', '籼型三系杂交稻', '科荟种业股份有限公司等', '国审稻20226114', '农业部']
# 3. ['843', '爽两优泰珍', '爽1S×泰真香', '籼型两系杂交稻', '西科农业集团股份有限公司等', '国审稻20226113', '农业部']
# 等待 2.48 秒后继续...
#
# ==============================
# 处理 农业部 第 26/122 页
# ==============================
# 正在爬取: https://www.ricedata.cn/variety/identified/nation_26.htm
# 使用编码: gbk
# 表格HTML片段: <table cellpadding="2" cellspacing="0" style="font-size:13; font-family:Times New Roman; border-top:solid black 2px; border-bottom:solid black 2px" width="1200"><tr align="left"><td height="30" width="50"><b>序号</b></td><td height="30" width="120"><b>品种名称</b></td><td><b>亲本来源（"×"前为母本）</b></td><td width="150"><b>类型</b></td><td><b>原产地/选育单位</b></td><td><b>审定编号</b></td></tr><caption style="text-align:right; font-size:13px; padding-top:15px;color: red"><b>农业部历年审定品种 4268 个：<a href="nation_1.htm" style="...
# 找到有效表头: ['序号', '品种名称', '亲本来源（"×"前为母本）', '类型', '原产地/选育单位', '审定编号']
# 获取到 35 条记录
# 已爬取第 26/122 页，获取 35 条记录
# 前3条数据样例:
# 1. ['876', '爽两优美丝', '爽1S×美雪丝苗2号', '籼型两系杂交稻', '西科农业集团股份有限公司等', '国审稻20226080', '农业部']
# 2. ['877', '爽两优182', '爽1S×天龙恢182', '籼型两系杂交稻', '西科农业集团股份有限公司', '国审稻20226079', '农业部']
# 3. ['878', '爽两优105', '爽1S×爽恢105', '籼型两系杂交稻', '西科农业集团股份有限公司等', '国审稻20226078', '农业部']
# 等待 1.99 秒后继续...
#
# ==============================
# 处理 农业部 第 27/122 页
# ==============================
# 正在爬取: https://www.ricedata.cn/variety/identified/nation_27.htm
# 使用编码: gbk
# 表格HTML片段: <table cellpadding="2" cellspacing="0" style="font-size:13; font-family:Times New Roman; border-top:solid black 2px; border-bottom:solid black 2px" width="1200"><tr align="left"><td height="30" width="50"><b>序号</b></td><td height="30" width="120"><b>品种名称</b></td><td><b>亲本来源（"×"前为母本）</b></td><td width="150"><b>类型</b></td><td><b>原产地/选育单位</b></td><td><b>审定编号</b></td></tr><caption style="text-align:right; font-size:13px; padding-top:15px;color: red"><b>农业部历年审定品种 4268 个：<a href="nation_1.htm" style="...
# 找到有效表头: ['序号', '品种名称', '亲本来源（"×"前为母本）', '类型', '原产地/选育单位', '审定编号']
# 获取到 35 条记录
# 已爬取第 27/122 页，获取 35 条记录
# 前3条数据样例:
# 1. ['911', '富两优2877', '富186S×中种恢2877', '籼型两系杂交稻', '中国种子集团有限公司', '国审稻20226045', '农业部']
# 2. ['912', '鄂丰优755', '鄂丰7A×R554', '籼型三系杂交稻', '湖北省种子集团有限公司', '国审稻20226044', '农业部']
# 3. ['913', '川种优3877', '川种3A×中种恢2877', '籼型三系杂交稻', '中国种子集团有限公司等', '国审稻20226043', '农业部']
# 等待 1.19 秒后继续...
#
# ==============================
# 处理 农业部 第 28/122 页
# ==============================
# 正在爬取: https://www.ricedata.cn/variety/identified/nation_28.htm
# 使用编码: gbk
# 表格HTML片段: <table cellpadding="2" cellspacing="0" style="font-size:13; font-family:Times New Roman; border-top:solid black 2px; border-bottom:solid black 2px" width="1200"><tr align="left"><td height="30" width="50"><b>序号</b></td><td height="30" width="120"><b>品种名称</b></td><td><b>亲本来源（"×"前为母本）</b></td><td width="150"><b>类型</b></td><td><b>原产地/选育单位</b></td><td><b>审定编号</b></td></tr><caption style="text-align:right; font-size:13px; padding-top:15px;color: red"><b>农业部历年审定品种 4268 个：<a href="nation_1.htm" style="...
# 找到有效表头: ['序号', '品种名称', '亲本来源（"×"前为母本）', '类型', '原产地/选育单位', '审定编号']
# 获取到 35 条记录
# 已爬取第 28/122 页，获取 35 条记录
# 前3条数据样例:
# 1. ['946', '国香优2115', '国乡1A×雅恢2115', '籼型三系杂交稻', '四川国豪种业股份有限公司等', '国审稻20226010', '农业部']
# 2. ['947', '国香优2103', '国香1A×渝恢2103', '籼型三系杂交稻', '四川国豪种业股份有限公司等', '国审稻20226009', '农业部']
# 3. ['948', '广泰优巴斯香占', '广泰A×巴斯香占', '籼型三系杂交稻', '安徽荃银高科种业股份有限公司等', '国审稻20226008', '农业部']
# 等待 1.95 秒后继续...
#
# ==============================
# 处理 农业部 第 29/122 页
# ==============================
# 正在爬取: https://www.ricedata.cn/variety/identified/nation_29.htm
# 使用编码: gbk
# 表格HTML片段: <table cellpadding="2" cellspacing="0" style="font-size:13; font-family:Times New Roman; border-top:solid black 2px; border-bottom:solid black 2px" width="1200"><tr align="left"><td height="30" width="50"><b>序号</b></td><td height="30" width="120"><b>品种名称</b></td><td><b>亲本来源（"×"前为母本）</b></td><td width="150"><b>类型</b></td><td><b>原产地/选育单位</b></td><td><b>审定编号</b></td></tr><caption style="text-align:right; font-size:13px; padding-top:15px;color: red"><b>农业部历年审定品种 4268 个：<a href="nation_1.htm" style="...
# 找到有效表头: ['序号', '品种名称', '亲本来源（"×"前为母本）', '类型', '原产地/选育单位', '审定编号']
# 获取到 35 条记录
# 已爬取第 29/122 页，获取 35 条记录
# 前3条数据样例:
# 1. ['981', '苏秀1902', 'NF27×SD29', '粳型常规稻', '江苏苏乐种业科技有限公司等', '国审稻20220281', '农业部']
# 2. ['982', '苏乐239', '苏秀10号×淮稻5号', '粳型常规稻', '江苏苏乐种业科技有限公司', '国审稻20220280', '农业部']
# 3. ['983', '圣稻1935', '南粳52×圣稻14', '粳型常规稻', '山东省水稻研究所', '国审稻20220279', '农业部']
# 等待 2.65 秒后继续...
#
# ==============================
# 处理 农业部 第 30/122 页
# ==============================
# 正在爬取: https://www.ricedata.cn/variety/identified/nation_30.htm
# 使用编码: gbk
# 表格HTML片段: <table cellpadding="2" cellspacing="0" style="font-size:13; font-family:Times New Roman; border-top:solid black 2px; border-bottom:solid black 2px" width="1200"><tr align="left"><td height="30" width="50"><b>序号</b></td><td height="30" width="120"><b>品种名称</b></td><td><b>亲本来源（"×"前为母本）</b></td><td width="150"><b>类型</b></td><td><b>原产地/选育单位</b></td><td><b>审定编号</b></td></tr><caption style="text-align:right; font-size:13px; padding-top:15px;color: red"><b>农业部历年审定品种 4268 个：<a href="nation_1.htm" style="...
# 找到有效表头: ['序号', '品种名称', '亲本来源（"×"前为母本）', '类型', '原产地/选育单位', '审定编号']
# 获取到 35 条记录
# 已爬取第 30/122 页，获取 35 条记录
# 前3条数据样例:
# 1. ['1016', '泰优农禾丝苗', '泰丰A×农禾丝苗', '籼型三系杂交稻', '江西现代种业股份有限公司等', '国审稻20220246', '农业部']
# 2. ['1017', '千乡955优651', '千乡955A×乐恢651', '籼型三系杂交稻', '福建农乐种业有限公司等', '国审稻20220245', '农业部']
# 3. ['1018', '那香优651', '那香107A×乐恢651', '籼型三系杂交稻', '福建农乐种业有限公司等', '国审稻20220244', '农业部']
# 等待 2.09 秒后继续...
#
# ==============================
# 处理 农业部 第 31/122 页
# ==============================
# 正在爬取: https://www.ricedata.cn/variety/identified/nation_31.htm
# 使用编码: gbk
# 表格HTML片段: <table cellpadding="2" cellspacing="0" style="font-size:13; font-family:Times New Roman; border-top:solid black 2px; border-bottom:solid black 2px" width="1200"><tr align="left"><td height="30" width="50"><b>序号</b></td><td height="30" width="120"><b>品种名称</b></td><td><b>亲本来源（"×"前为母本）</b></td><td width="150"><b>类型</b></td><td><b>原产地/选育单位</b></td><td><b>审定编号</b></td></tr><caption style="text-align:right; font-size:13px; padding-top:15px;color: red"><b>农业部历年审定品种 4268 个：<a href="nation_1.htm" style="...
# 找到有效表头: ['序号', '品种名称', '亲本来源（"×"前为母本）', '类型', '原产地/选育单位', '审定编号']
# 获取到 35 条记录
# 已爬取第 31/122 页，获取 35 条记录
# 前3条数据样例:
# 1. ['1051', '美香银占2号', '美香占2号×黄银占/丰太丝苗', '籼型常规稻', '福建科力种业有限公司等', '国审稻20220211', '农业部']
# 2. ['1052', '陵两优179', '湘陵628S×中09-179', '籼型两系杂交稻', '中国水稻研究所等', '国审稻20220210', '农业部']
# 3. ['1053', '坚两优58', 'HA1705S×M280', '籼型两系杂交稻', '安徽华安种业有限责任公司', '国审稻20220209', '农业部']
# 等待 2.03 秒后继续...
#
# ==============================
# 处理 农业部 第 32/122 页
# ==============================
# 正在爬取: https://www.ricedata.cn/variety/identified/nation_32.htm
# 使用编码: gbk
# 表格HTML片段: <table cellpadding="2" cellspacing="0" style="font-size:13; font-family:Times New Roman; border-top:solid black 2px; border-bottom:solid black 2px" width="1200"><tr align="left"><td height="30" width="50"><b>序号</b></td><td height="30" width="120"><b>品种名称</b></td><td><b>亲本来源（"×"前为母本）</b></td><td width="150"><b>类型</b></td><td><b>原产地/选育单位</b></td><td><b>审定编号</b></td></tr><caption style="text-align:right; font-size:13px; padding-top:15px;color: red"><b>农业部历年审定品种 4268 个：<a href="nation_1.htm" style="...
# 找到有效表头: ['序号', '品种名称', '亲本来源（"×"前为母本）', '类型', '原产地/选育单位', '审定编号']
# 获取到 35 条记录
# 已爬取第 32/122 页，获取 35 条记录
# 前3条数据样例:
# 1. ['1086', '泰2优393', '泰2A×泰恢3449-3', '籼型三系杂交稻', '泸州泰丰种业有限公司', '国审稻20220176', '农业部']
# 2. ['1087', '太两优香五', '泰香206S×R2055', '籼型两系杂交稻', '长沙碧盈农业科技有限公司', '国审稻20220175', '农业部']
# 3. ['1088', '硕两优215', '悦216S×悦恢15', '籼型两系杂交稻', '江苏悦丰种业科技有限公司', '国审稻20220174', '农业部']
# 等待 1.54 秒后继续...
#
# ==============================
# 处理 农业部 第 33/122 页
# ==============================
# 正在爬取: https://www.ricedata.cn/variety/identified/nation_33.htm
# 使用编码: gbk
# 表格HTML片段: <table cellpadding="2" cellspacing="0" style="font-size:13; font-family:Times New Roman; border-top:solid black 2px; border-bottom:solid black 2px" width="1200"><tr align="left"><td height="30" width="50"><b>序号</b></td><td height="30" width="120"><b>品种名称</b></td><td><b>亲本来源（"×"前为母本）</b></td><td width="150"><b>类型</b></td><td><b>原产地/选育单位</b></td><td><b>审定编号</b></td></tr><caption style="text-align:right; font-size:13px; padding-top:15px;color: red"><b>农业部历年审定品种 4268 个：<a href="nation_1.htm" style="...
# 找到有效表头: ['序号', '品种名称', '亲本来源（"×"前为母本）', '类型', '原产地/选育单位', '审定编号']
# 获取到 35 条记录
# 已爬取第 33/122 页，获取 35 条记录
# 前3条数据样例:
# 1. ['1121', '凯两优99', '凯11S×R099', '籼型两系杂交稻', '安徽凯利种业有限公司', '国审稻20220141', '农业部']
# 2. ['1122', '君两优丝苗', '君S×君禾丝苗', '籼型两系杂交稻', '建阳民丰农作物品种研究所等', '国审稻20220140', '农业部']
# 3. ['1123', '巨2优96', '巨风2A×R96', '籼型三系杂交稻', '荆州农业科学院等', '国审稻20220139', '农业部']
# 等待 1.27 秒后继续...
#
# ==============================
# 处理 农业部 第 34/122 页
# ==============================
# 正在爬取: https://www.ricedata.cn/variety/identified/nation_34.htm
# 使用编码: gbk
# 表格HTML片段: <table cellpadding="2" cellspacing="0" style="font-size:13; font-family:Times New Roman; border-top:solid black 2px; border-bottom:solid black 2px" width="1200"><tr align="left"><td height="30" width="50"><b>序号</b></td><td height="30" width="120"><b>品种名称</b></td><td><b>亲本来源（"×"前为母本）</b></td><td width="150"><b>类型</b></td><td><b>原产地/选育单位</b></td><td><b>审定编号</b></td></tr><caption style="text-align:right; font-size:13px; padding-top:15px;color: red"><b>农业部历年审定品种 4268 个：<a href="nation_1.htm" style="...
# 找到有效表头: ['序号', '品种名称', '亲本来源（"×"前为母本）', '类型', '原产地/选育单位', '审定编号']
# 获取到 35 条记录
# 已爬取第 34/122 页，获取 35 条记录
# 前3条数据样例:
# 1. ['1156', '邦两优郁香', '邦S×郁香', '籼型两系杂交稻', '广西兆和种业有限公司', '国审稻20220106', '农业部']
# 2. ['1157', '安两优305', '安隆5S×R305', '籼型两系杂交稻', '合肥信达高科农业科学研究所等', '国审稻20220105', '农业部']
# 3. ['1158', 'Q两优粤五丝苗', '全151S×粤标5号', '籼型两系杂交稻', '安徽荃银种业科技有限公司等', '国审稻20220104', '农业部']
# 等待 2.41 秒后继续...
#
# ==============================
# 处理 农业部 第 35/122 页
# ==============================
# 正在爬取: https://www.ricedata.cn/variety/identified/nation_35.htm
# 使用编码: gbk
# 表格HTML片段: <table cellpadding="2" cellspacing="0" style="font-size:13; font-family:Times New Roman; border-top:solid black 2px; border-bottom:solid black 2px" width="1200"><tr align="left"><td height="30" width="50"><b>序号</b></td><td height="30" width="120"><b>品种名称</b></td><td><b>亲本来源（"×"前为母本）</b></td><td width="150"><b>类型</b></td><td><b>原产地/选育单位</b></td><td><b>审定编号</b></td></tr><caption style="text-align:right; font-size:13px; padding-top:15px;color: red"><b>农业部历年审定品种 4268 个：<a href="nation_1.htm" style="...
# 找到有效表头: ['序号', '品种名称', '亲本来源（"×"前为母本）', '类型', '原产地/选育单位', '审定编号']
# 获取到 35 条记录
# 已爬取第 35/122 页，获取 35 条记录
# 前3条数据样例:
# 1. ['1191', '奇两优郁香', '奇S×郁香', '籼型两系杂交稻', '广西南宁依久农业发展有限公司', '国审稻20220071', '农业部']
# 2. ['1192', '品香优润丝', '品香A×德恢润丝', '籼型三系杂交稻', '四川省农业科学院水稻高粱研究所', '国审稻20220070', '农业部']
# 3. ['1193', '鹏优5627', '鹏A×R5627', '籼型三系杂交稻', '广东和丰种业科技有限公司', '国审稻20220069', '农业部']
# 等待 1.62 秒后继续...
#
# ==============================
# 处理 农业部 第 36/122 页
# ==============================
# 正在爬取: https://www.ricedata.cn/variety/identified/nation_36.htm
# 使用编码: gbk
# 表格HTML片段: <table cellpadding="2" cellspacing="0" style="font-size:13; font-family:Times New Roman; border-top:solid black 2px; border-bottom:solid black 2px" width="1200"><tr align="left"><td height="30" width="50"><b>序号</b></td><td height="30" width="120"><b>品种名称</b></td><td><b>亲本来源（"×"前为母本）</b></td><td width="150"><b>类型</b></td><td><b>原产地/选育单位</b></td><td><b>审定编号</b></td></tr><caption style="text-align:right; font-size:13px; padding-top:15px;color: red"><b>农业部历年审定品种 4268 个：<a href="nation_1.htm" style="...
# 找到有效表头: ['序号', '品种名称', '亲本来源（"×"前为母本）', '类型', '原产地/选育单位', '审定编号']
# 获取到 35 条记录
# 已爬取第 36/122 页，获取 35 条记录
# 前3条数据样例:
# 1. ['1226', '北0619', '五优稻1号/8709×北稻2号', '粳型常规稻', '黑龙江省北方稻作研究所', '国审稻20220036', '农业部']
# 2. ['1227', '新科稻58', '新科稻31×新稻89/新稻10号', '粳型常规稻', '河南省新乡市农业科学院', '国审稻20220035', '农业部']
# 3. ['1228', '京粳6号', '大粮203×大粮203/垦稻2016', '粳型常规稻', '中国农业科学院作物科学研究所', '国审稻20220034', '农业部']
# 等待 1.13 秒后继续...
#
# ==============================
# 处理 农业部 第 37/122 页
# ==============================
# 正在爬取: https://www.ricedata.cn/variety/identified/nation_37.htm
# 使用编码: gbk
# 表格HTML片段: <table cellpadding="2" cellspacing="0" style="font-size:13; font-family:Times New Roman; border-top:solid black 2px; border-bottom:solid black 2px" width="1200"><tr align="left"><td height="30" width="50"><b>序号</b></td><td height="30" width="120"><b>品种名称</b></td><td><b>亲本来源（"×"前为母本）</b></td><td width="150"><b>类型</b></td><td><b>原产地/选育单位</b></td><td><b>审定编号</b></td></tr><caption style="text-align:right; font-size:13px; padding-top:15px;color: red"><b>农业部历年审定品种 4268 个：<a href="nation_1.htm" style="...
# 找到有效表头: ['序号', '品种名称', '亲本来源（"×"前为母本）', '类型', '原产地/选育单位', '审定编号']
# 获取到 35 条记录
# 已爬取第 37/122 页，获取 35 条记录
# 前3条数据样例:
# 1. ['1261', '黄广农占', '黄广油占×五广占/丰粤华占', '籼型常规稻', '广东省农业科学院水稻研究所', '国审稻20220001', '农业部']
# 2. ['1262', '宁粳15号', '武运0175×淮9702/徐稻3号', '粳型常规稻', '袁隆平农业高科技股份有限公司等', '国审稻20216225', '农业部']
# 3. ['1263', '宁粳14号', '宁粳7号×08W2188', '粳型常规稻', '袁隆平农业高科技股份有限公司等', '国审稻20216224', '农业部']
# 等待 1.13 秒后继续...
#
# ==============================
# 处理 农业部 第 38/122 页
# ==============================
# 正在爬取: https://www.ricedata.cn/variety/identified/nation_38.htm
# 使用编码: gbk
# 表格HTML片段: <table cellpadding="2" cellspacing="0" style="font-size:13; font-family:Times New Roman; border-top:solid black 2px; border-bottom:solid black 2px" width="1200"><tr align="left"><td height="30" width="50"><b>序号</b></td><td height="30" width="120"><b>品种名称</b></td><td><b>亲本来源（"×"前为母本）</b></td><td width="150"><b>类型</b></td><td><b>原产地/选育单位</b></td><td><b>审定编号</b></td></tr><caption style="text-align:right; font-size:13px; padding-top:15px;color: red"><b>农业部历年审定品种 4268 个：<a href="nation_1.htm" style="...
# 找到有效表头: ['序号', '品种名称', '亲本来源（"×"前为母本）', '类型', '原产地/选育单位', '审定编号']
# 获取到 35 条记录
# 已爬取第 38/122 页，获取 35 条记录
# 前3条数据样例:
# 1. ['1296', '晖两优2646', '华晖217S×华恢2646', '籼型两系杂交稻', '袁隆平农业高科技股份有限公司等', '国审稻20216191', '农业部']
# 2. ['1297', '泰优390', '泰丰A×广恢390', '籼型三系杂交稻', '湖南金稻种业有限公司等', '国审稻20216190', '农业部']
# 3. ['1298', '晖两优泰丝', '华晖217S×泰丝', '籼型两系杂交稻', '袁隆平农业高科技股份有限公司等', '国审稻20216189', '农业部']
# 等待 2.80 秒后继续...
#
# ==============================
# 处理 农业部 第 39/122 页
# ==============================
# 正在爬取: https://www.ricedata.cn/variety/identified/nation_39.htm
# 使用编码: gbk
# 表格HTML片段: <table cellpadding="2" cellspacing="0" style="font-size:13; font-family:Times New Roman; border-top:solid black 2px; border-bottom:solid black 2px" width="1200"><tr align="left"><td height="30" width="50"><b>序号</b></td><td height="30" width="120"><b>品种名称</b></td><td><b>亲本来源（"×"前为母本）</b></td><td width="150"><b>类型</b></td><td><b>原产地/选育单位</b></td><td><b>审定编号</b></td></tr><caption style="text-align:right; font-size:13px; padding-top:15px;color: red"><b>农业部历年审定品种 4268 个：<a href="nation_1.htm" style="...
# 找到有效表头: ['序号', '品种名称', '亲本来源（"×"前为母本）', '类型', '原产地/选育单位', '审定编号']
# 获取到 35 条记录
# 已爬取第 39/122 页，获取 35 条记录
# 前3条数据样例:
# 1. ['1331', '银两优506', '银312S×5HR015', '籼型两系杂交稻', '安徽荃银高科种业股份有限公司等', '国审稻20216156', '农业部']
# 2. ['1332', '银两优洁田丝苗', '银312S×洁田丝苗', '籼型两系杂交稻', '安徽荃银高科种业股份有限公司', '国审稻20216155', '农业部']
# 3. ['1333', '赣73优220', '赣73A×苏恢220', '籼型三系杂交稻', '江苏中江种业股份有限公司等', '国审稻20216154', '农业部']
# 等待 1.33 秒后继续...
#
# ==============================
# 处理 农业部 第 40/122 页
# ==============================
# 正在爬取: https://www.ricedata.cn/variety/identified/nation_40.htm
# 使用编码: gbk
# 表格HTML片段: <table cellpadding="2" cellspacing="0" style="font-size:13; font-family:Times New Roman; border-top:solid black 2px; border-bottom:solid black 2px" width="1200"><tr align="left"><td height="30" width="50"><b>序号</b></td><td height="30" width="120"><b>品种名称</b></td><td><b>亲本来源（"×"前为母本）</b></td><td width="150"><b>类型</b></td><td><b>原产地/选育单位</b></td><td><b>审定编号</b></td></tr><caption style="text-align:right; font-size:13px; padding-top:15px;color: red"><b>农业部历年审定品种 4268 个：<a href="nation_1.htm" style="...
# 找到有效表头: ['序号', '品种名称', '亲本来源（"×"前为母本）', '类型', '原产地/选育单位', '审定编号']
# 获取到 35 条记录
# 已爬取第 40/122 页，获取 35 条记录
# 前3条数据样例:
# 1. ['1366', '菁两优685', '菁农S×荟恢685', '籼型两系杂交稻', '科荟种业股份有公司', '国审稻20216121', '农业部']
# 2. ['1367', '杉两优636', '杉农S×荟恢636', '籼型两系杂交稻', '科荟种业股份有限公司', '国审稻20216120', '农业部']
# 3. ['1368', '万丰优957', '万丰99A×创恢957', '籼型三系杂交稻', '湖南袁创超级稻技术有限公司', '国审稻20216119', '农业部']
# 等待 1.03 秒后继续...
#
# ==============================
# 处理 农业部 第 41/122 页
# ==============================
# 正在爬取: https://www.ricedata.cn/variety/identified/nation_41.htm
# 使用编码: gbk
# 表格HTML片段: <table cellpadding="2" cellspacing="0" style="font-size:13; font-family:Times New Roman; border-top:solid black 2px; border-bottom:solid black 2px" width="1200"><tr align="left"><td height="30" width="50"><b>序号</b></td><td height="30" width="120"><b>品种名称</b></td><td><b>亲本来源（"×"前为母本）</b></td><td width="150"><b>类型</b></td><td><b>原产地/选育单位</b></td><td><b>审定编号</b></td></tr><caption style="text-align:right; font-size:13px; padding-top:15px;color: red"><b>农业部历年审定品种 4268 个：<a href="nation_1.htm" style="...
# 找到有效表头: ['序号', '品种名称', '亲本来源（"×"前为母本）', '类型', '原产地/选育单位', '审定编号']
# 获取到 35 条记录
# 已爬取第 41/122 页，获取 35 条记录
# 前3条数据样例:
# 1. ['1401', '荃两优532', '荃211S×YH532', '籼型两系杂交稻', '安徽荃银高科种业股份有限公司', '国审稻20216086', '农业部']
# 2. ['1402', '荃广优822', '荃广A×YR0822', '籼型三系杂交稻', '安徽荃银高科种业股份有限公司', '国审稻20216085', '农业部']
# 3. ['1403', '桃两优33', '桃HS×TR336', '籼型两系杂交稻', '湖南桃花源农业科技股份有限公司等', '国审稻20216084', '农业部']
# 等待 1.42 秒后继续...
#
# ==============================
# 处理 农业部 第 42/122 页
# ==============================
# 正在爬取: https://www.ricedata.cn/variety/identified/nation_42.htm
# 使用编码: gbk
# 表格HTML片段: <table cellpadding="2" cellspacing="0" style="font-size:13; font-family:Times New Roman; border-top:solid black 2px; border-bottom:solid black 2px" width="1200"><tr align="left"><td height="30" width="50"><b>序号</b></td><td height="30" width="120"><b>品种名称</b></td><td><b>亲本来源（"×"前为母本）</b></td><td width="150"><b>类型</b></td><td><b>原产地/选育单位</b></td><td><b>审定编号</b></td></tr><caption style="text-align:right; font-size:13px; padding-top:15px;color: red"><b>农业部历年审定品种 4268 个：<a href="nation_1.htm" style="...
# 找到有效表头: ['序号', '品种名称', '亲本来源（"×"前为母本）', '类型', '原产地/选育单位', '审定编号']
# 获取到 35 条记录
# 已爬取第 42/122 页，获取 35 条记录
# 前3条数据样例:
# 1. ['1436', '桃两优2号', '桃HS×TR776', '籼型两系杂交稻', '湖南桃花源农业科技股份有限公司等', '国审稻20216051', '农业部']
# 2. ['1437', '香龙优263', '香龙A×中种恢263', '籼型三系杂交稻', '中国种子集团有限公司等', '国审稻20216050', '农业部']
# 3. ['1438', '金龙优263', '金龙A×中种恢263', '籼型三系杂交稻', '中国种子集团有限公司等', '国审稻20216049', '农业部']
# 等待 1.35 秒后继续...
#
# ==============================
# 处理 农业部 第 43/122 页
# ==============================
# 正在爬取: https://www.ricedata.cn/variety/identified/nation_43.htm
# 使用编码: gbk
# 表格HTML片段: <table cellpadding="2" cellspacing="0" style="font-size:13; font-family:Times New Roman; border-top:solid black 2px; border-bottom:solid black 2px" width="1200"><tr align="left"><td height="30" width="50"><b>序号</b></td><td height="30" width="120"><b>品种名称</b></td><td><b>亲本来源（"×"前为母本）</b></td><td width="150"><b>类型</b></td><td><b>原产地/选育单位</b></td><td><b>审定编号</b></td></tr><caption style="text-align:right; font-size:13px; padding-top:15px;color: red"><b>农业部历年审定品种 4268 个：<a href="nation_1.htm" style="...
# 找到有效表头: ['序号', '品种名称', '亲本来源（"×"前为母本）', '类型', '原产地/选育单位', '审定编号']
# 获取到 35 条记录
# 已爬取第 43/122 页，获取 35 条记录
# 前3条数据样例:
# 1. ['1471', '荃优银泰香占', '荃9311A×银泰香占', '籼型三系杂交稻', '安徽荃银高科种业股份有限公司', '国审稻20216016', '农业部']
# 2. ['1472', '荃两优1606', '荃211S×YR1606', '籼型两系杂交稻', '安徽荃银高科种业股份有限公司', '国审稻20216015', '农业部']
# 3. ['1473', '荃广优851', '荃广A×YR851', '籼型三系杂交稻', '安徽荃银高科种业股份有限公司', '国审稻20216014', '农业部']
# 等待 1.62 秒后继续...
#
# ==============================
# 处理 农业部 第 44/122 页
# ==============================
# 正在爬取: https://www.ricedata.cn/variety/identified/nation_44.htm
# 使用编码: gbk
# 表格HTML片段: <table cellpadding="2" cellspacing="0" style="font-size:13; font-family:Times New Roman; border-top:solid black 2px; border-bottom:solid black 2px" width="1200"><tr align="left"><td height="30" width="50"><b>序号</b></td><td height="30" width="120"><b>品种名称</b></td><td><b>亲本来源（"×"前为母本）</b></td><td width="150"><b>类型</b></td><td><b>原产地/选育单位</b></td><td><b>审定编号</b></td></tr><caption style="text-align:right; font-size:13px; padding-top:15px;color: red"><b>农业部历年审定品种 4268 个：<a href="nation_1.htm" style="...
# 找到有效表头: ['序号', '品种名称', '亲本来源（"×"前为母本）', '类型', '原产地/选育单位', '审定编号']
# 获取到 35 条记录
# 已爬取第 44/122 页，获取 35 条记录
# 前3条数据样例:
# 1. ['1506', '通禾861', '平粳8号×吉粳88号/通禾08-6195', '粳型常规稻', '通化市农业科学研究院', '国审稻20210433', '农业部']
# 2. ['1507', '京粳7号', '中作1058×密阳84', '粳型常规稻', '中国农业科学院作物科学研究所', '国审稻20210432', '农业部']
# 3. ['1508', '锦稻108', 'PF309', '粳型常规稻', '盘锦北方农业技术开发有限公司', '国审稻20210431', '农业部']
# 等待 1.48 秒后继续...
#
# ==============================
# 处理 农业部 第 45/122 页
# ==============================
# 正在爬取: https://www.ricedata.cn/variety/identified/nation_45.htm
# 使用编码: gbk
# 表格HTML片段: <table cellpadding="2" cellspacing="0" style="font-size:13; font-family:Times New Roman; border-top:solid black 2px; border-bottom:solid black 2px" width="1200"><tr align="left"><td height="30" width="50"><b>序号</b></td><td height="30" width="120"><b>品种名称</b></td><td><b>亲本来源（"×"前为母本）</b></td><td width="150"><b>类型</b></td><td><b>原产地/选育单位</b></td><td><b>审定编号</b></td></tr><caption style="text-align:right; font-size:13px; padding-top:15px;color: red"><b>农业部历年审定品种 4268 个：<a href="nation_1.htm" style="...
# 找到有效表头: ['序号', '品种名称', '亲本来源（"×"前为母本）', '类型', '原产地/选育单位', '审定编号']
# 获取到 35 条记录
# 已爬取第 45/122 页，获取 35 条记录
# 前3条数据样例:
# 1. ['1541', '新粮12号', '郑稻19×五粳04136', '粳型常规稻', '新乡市新粮水稻研究所', '国审稻20210398', '农业部']
# ...
# 等待 1.33 秒后继续...
#
# ==============================
# 处理 贵州 第 12/15 页
# ==============================
# 正在爬取: https://www.ricedata.cn/variety/identified/gvvb_12.htm
# 使用编码: gbk
# 表格HTML片段: <table cellpadding="2" cellspacing="0" style="font-size:13; font-family:Times New Roman; border-top:solid black 2px; border-bottom:solid black 2px" width="1200"><tr align="left"><td height="30" width="50"><b>序号</b></td><td height="30" width="120"><b>品种名称</b></td><td><b>亲本来源（"×"前为母本）</b></td><td width="150"><b>类型</b></td><td><b>原产地/选育单位</b></td><td><b>审定编号</b></td></tr><caption style="text-align:right; font-size:13px; padding-top:15px;color: red"><b>贵州省历年审定品种 507 个：<a href="gvvb_1.htm" style="fon...
# 找到有效表头: ['序号', '品种名称', '亲本来源（"×"前为母本）', '类型', '原产地/选育单位', '审定编号']
# 获取到 35 条记录
# 已爬取第 12/15 页，获取 35 条记录
# 前3条数据样例:
# 1. ['386', '汕优456', '珍汕97A×R456', '籼型三系杂交稻', '贵州德农种业有限责任公司', '黔审稻2004001号', '贵州']
# 2. ['387', '毕粳41号', '合系25号×六粳2号', '粳型常规稻', '贵州省毕节地区农业科学研究所', '黔审稻2003019号', '贵州']
# 3. ['388', '溪香A', '香优63', '籼型不育系', '贵州大学农学院水稻研究所', '黔审稻2003018号', '贵州']
# 等待 1.87 秒后继续...
#
# ==============================
# 处理 贵州 第 13/15 页
# ==============================
# 正在爬取: https://www.ricedata.cn/variety/identified/gvvb_13.htm
# 使用编码: gbk
# 表格HTML片段: <table cellpadding="2" cellspacing="0" style="font-size:13; font-family:Times New Roman; border-top:solid black 2px; border-bottom:solid black 2px" width="1200"><tr align="left"><td height="30" width="50"><b>序号</b></td><td height="30" width="120"><b>品种名称</b></td><td><b>亲本来源（"×"前为母本）</b></td><td width="150"><b>类型</b></td><td><b>原产地/选育单位</b></td><td><b>审定编号</b></td></tr><caption style="text-align:right; font-size:13px; padding-top:15px;color: red"><b>贵州省历年审定品种 507 个：<a href="gvvb_1.htm" style="fon...
# 找到有效表头: ['序号', '品种名称', '亲本来源（"×"前为母本）', '类型', '原产地/选育单位', '审定编号']
# 获取到 35 条记录
# 已爬取第 13/15 页，获取 35 条记录
# 前3条数据样例:
# 1. ['421', 'Ⅱ优58', 'Ⅱ-32A×恩恢58', '籼型三系杂交稻', '湖北省恩施自治州红庙农科所', '黔品审251号', '贵州']
# 2. ['422', 'Ⅱ优多系1号', 'Ⅱ-32A×多系1号', '籼型三系杂交稻', '内江杂交水稻科技开发中心', '黔品审250号', '贵州']
# 3. ['423', 'Ⅱ优63', 'Ⅱ-32A×明恢63', '籼型三系杂交稻', '湖南杂交水稻研究中心', '黔品审249号', '贵州']
# 等待 2.60 秒后继续...
#
# ==============================
# 处理 贵州 第 14/15 页
# ==============================
# 正在爬取: https://www.ricedata.cn/variety/identified/gvvb_14.htm
# 使用编码: gbk
# 表格HTML片段: <table cellpadding="2" cellspacing="0" style="font-size:13; font-family:Times New Roman; border-top:solid black 2px; border-bottom:solid black 2px" width="1200"><tr align="left"><td height="30" width="50"><b>序号</b></td><td height="30" width="120"><b>品种名称</b></td><td><b>亲本来源（"×"前为母本）</b></td><td width="150"><b>类型</b></td><td><b>原产地/选育单位</b></td><td><b>审定编号</b></td></tr><caption style="text-align:right; font-size:13px; padding-top:15px;color: red"><b>贵州省历年审定品种 507 个：<a href="gvvb_1.htm" style="fon...
# 找到有效表头: ['序号', '品种名称', '亲本来源（"×"前为母本）', '类型', '原产地/选育单位', '审定编号']
# 获取到 35 条记录
# 已爬取第 14/15 页，获取 35 条记录
# 前3条数据样例:
# 1. ['456', '黔南糯4号', '白糯×国青2号', '粳型常规稻', '贵州省黔南州农科所', '黔品审194号', '贵州']
# 2. ['457', '黔南糯3号', '白糯×成糯24', '粳型常规稻', '贵州省黔南州农科所', '黔品审193号', '贵州']
# 3. ['458', '黑糯93', '黑糯84×成糯24', '粳型常规稻', '贵州省黔南州农科所', '黔品审165号', '贵州']
# 等待 1.09 秒后继续...
#
# ==============================
# 处理 贵州 第 15/15 页
# ==============================
# 正在爬取: https://www.ricedata.cn/variety/identified/gvvb_15.htm
# 使用编码: gbk
# 表格HTML片段: <table cellpadding="2" cellspacing="0" style="font-size:13; font-family:Times New Roman; border-top:solid black 2px; border-bottom:solid black 2px" width="1200"><tr align="left"><td height="30" width="50"><b>序号</b></td><td height="30" width="120"><b>品种名称</b></td><td><b>亲本来源（"×"前为母本）</b></td><td width="150"><b>类型</b></td><td><b>原产地/选育单位</b></td><td><b>审定编号</b></td></tr><caption style="text-align:right; font-size:13px; padding-top:15px;color: red"><b>贵州省历年审定品种 507 个：<a href="gvvb_1.htm" style="fon...
# 找到有效表头: ['序号', '品种名称', '亲本来源（"×"前为母本）', '类型', '原产地/选育单位', '审定编号']
# 获取到 17 条记录
# 已爬取第 15/15 页，获取 17 条记录
# 前3条数据样例:
# 1. ['491', '黑糯141', '金矮选×摆榜高秆黑糯', '粳型常规稻', '贵州省惠水县科协', '黔稻17号', '贵州']
# 2. ['492', '毕粳80号', '?', '粳型常规稻', '贵州省毕节地区农科所', '黔稻16号', '贵州']
# 3. ['493', '铜籼1号', '72-12/Patuy×百日早', '籼型常规稻', '贵州省铜仁地区农业科学研究所', '黔稻15号', '贵州']
# 等待 1.15 秒后继续...
# 已保存 507 条数据到 rice_data/贵州水稻数据.csv
# 已完成 贵州 的数据采集，获取 507 条记录
# 等待 3.20 秒后处理下一个省份...
#
# ############################################################
# 开始处理: 重庆 (31/31)
# ############################################################
# 获取总页数: https://www.ricedata.cn/variety/identified/isqy_1.htm
# 使用编码: gbk
# 从末页链接提取总页数: 11
#
# 开始爬取 重庆 数据，共 11/11 页...
#
# ==============================
# 处理 重庆 第 1/11 页
# ==============================
# 正在爬取: https://www.ricedata.cn/variety/identified/isqy_1.htm
# 使用编码: gbk
# 表格HTML片段: <table cellpadding="2" cellspacing="0" style="font-size:13; font-family:Times New Roman; border-top:solid black 2px; border-bottom:solid black 2px" width="1200"><tr align="left"><td height="30" width="50"><b>序号</b></td><td height="30" width="120"><b>品种名称</b></td><td><b>亲本来源（"×"前为母本）</b></td><td width="150"><b>类型</b></td><td><b>原产地/选育单位</b></td><td><b>审定编号</b></td></tr><caption style="text-align:right; font-size:13px; padding-top:15px;color: red"><b>重庆市历年审定品种 357 个：<a href="isqy_1.htm" style="fon...
# 找到有效表头: ['序号', '品种名称', '亲本来源（"×"前为母本）', '类型', '原产地/选育单位', '审定编号']
# 获取到 35 条记录
# 表头: ['序号', '品种名称', '亲本来源（"×"前为母本）', '类型', '原产地/选育单位', '审定编号']
# 已爬取第 1/11 页，获取 35 条记录
# 前3条数据样例:
# 1. ['1', '师稻彩叶9号', '紫叶水稻IR1552/小红稻×师稻660', '籼型常规稻', '重庆师范大学', '渝审稻20240015', '重庆']
# 2. ['2', '巴黑糯4号', '巴黑糯1号/内恢99-14×巴恢98', '籼型常规稻', '重庆大学', '渝审稻20240014', '重庆']
# 3. ['3', '西紫优4号', '西紫1A×西恢28', '籼型三系杂交稻', '西南大学农学与生物科技学院', '渝审稻20240013', '重庆']
# 等待 2.72 秒后继续...
#
# ==============================
# 处理 重庆 第 2/11 页
# ==============================
# 正在爬取: https://www.ricedata.cn/variety/identified/isqy_2.htm
# 使用编码: gbk
# 表格HTML片段: <table cellpadding="2" cellspacing="0" style="font-size:13; font-family:Times New Roman; border-top:solid black 2px; border-bottom:solid black 2px" width="1200"><tr align="left"><td height="30" width="50"><b>序号</b></td><td height="30" width="120"><b>品种名称</b></td><td><b>亲本来源（"×"前为母本）</b></td><td width="150"><b>类型</b></td><td><b>原产地/选育单位</b></td><td><b>审定编号</b></td></tr><caption style="text-align:right; font-size:13px; padding-top:15px;color: red"><b>重庆市历年审定品种 357 个：<a href="isqy_1.htm" style="fon...
# 找到有效表头: ['序号', '品种名称', '亲本来源（"×"前为母本）', '类型', '原产地/选育单位', '审定编号']
# 获取到 35 条记录
# 已爬取第 2/11 页，获取 35 条记录
# 前3条数据样例:
# 1. ['36', '西大香2优26', '西大香2A×西恢26', '籼型三系杂交稻', '西南大学农学与生物科技学院', '渝审稻20230006', '重庆']
# 2. ['37', '陵香优19', '陵香1A×涪恢6019', '籼型三系杂交稻', '重庆市渝东南农业科学院', '渝审稻20230005', '重庆']
# 3. ['38', '玉龙优7号', '玉龙1A×锦城恢474', '籼型三系杂交稻', '成都市农林科学院作物研究所等', '渝审稻20230004', '重庆']
# 等待 1.60 秒后继续...
#
# ==============================
# 处理 重庆 第 3/11 页
# ==============================
# 正在爬取: https://www.ricedata.cn/variety/identified/isqy_3.htm
# 使用编码: gbk
# 表格HTML片段: <table cellpadding="2" cellspacing="0" style="font-size:13; font-family:Times New Roman; border-top:solid black 2px; border-bottom:solid black 2px" width="1200"><tr align="left"><td height="30" width="50"><b>序号</b></td><td height="30" width="120"><b>品种名称</b></td><td><b>亲本来源（"×"前为母本）</b></td><td width="150"><b>类型</b></td><td><b>原产地/选育单位</b></td><td><b>审定编号</b></td></tr><caption style="text-align:right; font-size:13px; padding-top:15px;color: red"><b>重庆市历年审定品种 357 个：<a href="isqy_1.htm" style="fon...
# 找到有效表头: ['序号', '品种名称', '亲本来源（"×"前为母本）', '类型', '原产地/选育单位', '审定编号']
# 获取到 35 条记录
# 已爬取第 3/11 页，获取 35 条记录
# 前3条数据样例:
# 1. ['71', '西大淡叶3号', '缙恢10号', '籼型常规稻', '西南大学农学与生物科技学院', '渝审稻20210025', '重庆']
# 2. ['72', '西大淡叶1号', '缙恢10号', '籼型常规稻', '西南大学农学与生物科技学院', '渝审稻20210024', '重庆']
# 3. ['73', '渝紫叶689', '白壳糯×辽粳294/稗草复粒稻', '粳型常规稻', '重庆市农业科学院等', '渝审稻20210023', '重庆']
# 等待 1.82 秒后继续...
#
# ==============================
# 处理 重庆 第 4/11 页
# ==============================
# 正在爬取: https://www.ricedata.cn/variety/identified/isqy_4.htm
# 使用编码: gbk
# 表格HTML片段: <table cellpadding="2" cellspacing="0" style="font-size:13; font-family:Times New Roman; border-top:solid black 2px; border-bottom:solid black 2px" width="1200"><tr align="left"><td height="30" width="50"><b>序号</b></td><td height="30" width="120"><b>品种名称</b></td><td><b>亲本来源（"×"前为母本）</b></td><td width="150"><b>类型</b></td><td><b>原产地/选育单位</b></td><td><b>审定编号</b></td></tr><caption style="text-align:right; font-size:13px; padding-top:15px;color: red"><b>重庆市历年审定品种 357 个：<a href="isqy_1.htm" style="fon...
# 找到有效表头: ['序号', '品种名称', '亲本来源（"×"前为母本）', '类型', '原产地/选育单位', '审定编号']
# 获取到 35 条记录
# 已爬取第 4/11 页，获取 35 条记录
# 前3条数据样例:
# 1. ['106', '祥优609', '祥丰A×帮恢609', '籼型三系杂交稻', '重庆市迪卡农业有限公司', '渝审稻20200024', '重庆']
# 2. ['107', '启优609', '启源A×帮恢609', '籼型三系杂交稻', '重庆帮豪种业股份有限公司等', '渝审稻20200023', '重庆']
# 3. ['108', 'Y两优305', 'Y58S×P305', '籼型两系杂交稻', '国家杂交水稻工程技术研究中心等', '渝审稻20200022', '重庆']
# 等待 1.69 秒后继续...
#
# ==============================
# 处理 重庆 第 5/11 页
# ==============================
# 正在爬取: https://www.ricedata.cn/variety/identified/isqy_5.htm
# 使用编码: gbk
# 表格HTML片段: <table cellpadding="2" cellspacing="0" style="font-size:13; font-family:Times New Roman; border-top:solid black 2px; border-bottom:solid black 2px" width="1200"><tr align="left"><td height="30" width="50"><b>序号</b></td><td height="30" width="120"><b>品种名称</b></td><td><b>亲本来源（"×"前为母本）</b></td><td width="150"><b>类型</b></td><td><b>原产地/选育单位</b></td><td><b>审定编号</b></td></tr><caption style="text-align:right; font-size:13px; padding-top:15px;color: red"><b>重庆市历年审定品种 357 个：<a href="isqy_1.htm" style="fon...
# 找到有效表头: ['序号', '品种名称', '亲本来源（"×"前为母本）', '类型', '原产地/选育单位', '审定编号']
# 获取到 35 条记录
# 已爬取第 5/11 页，获取 35 条记录
# 前3条数据样例:
# 1. ['141', 'U8优528', 'U8A×蜀恢528', '籼型三系杂交稻', '重庆本硕博农业发展有限公司等', '渝审稻20190005', '重庆']
# 2. ['142', '川优712', '川317A×SCR12', '籼型三系杂交稻', '四川省农业科学院水稻高粱研究所等', '渝审稻20190004', '重庆']
# 3. ['143', '川优5715', '川345A×德恢715', '籼型三系杂交稻', '四川省农业科学院水稻高粱研究所等', '渝审稻20190003', '重庆']
# 等待 1.53 秒后继续...
#
# ==============================
# 处理 重庆 第 6/11 页
# ==============================
# 正在爬取: https://www.ricedata.cn/variety/identified/isqy_6.htm
# 使用编码: gbk
# 表格HTML片段: <table cellpadding="2" cellspacing="0" style="font-size:13; font-family:Times New Roman; border-top:solid black 2px; border-bottom:solid black 2px" width="1200"><tr align="left"><td height="30" width="50"><b>序号</b></td><td height="30" width="120"><b>品种名称</b></td><td><b>亲本来源（"×"前为母本）</b></td><td width="150"><b>类型</b></td><td><b>原产地/选育单位</b></td><td><b>审定编号</b></td></tr><caption style="text-align:right; font-size:13px; padding-top:15px;color: red"><b>重庆市历年审定品种 357 个：<a href="isqy_1.htm" style="fon...
# 找到有效表头: ['序号', '品种名称', '亲本来源（"×"前为母本）', '类型', '原产地/选育单位', '审定编号']
# 获取到 35 条记录
# 已爬取第 6/11 页，获取 35 条记录
# 前3条数据样例:
# 1. ['176', '万优56', '万73A×万恢56', '籼型三系杂交稻', '重庆三峡农业科学院', '渝审稻20170007', '重庆']
# 2. ['177', '神农优228', '神农2A×Q恢28', '籼型三系杂交稻', '重庆中一种业有限公司', '渝审稻20170006', '重庆']
# 3. ['178', '陵优8724', '陵8A×涪恢0724', '籼型三系杂交稻', '绵阳市特丰种业有限公司等', '渝审稻20170005', '重庆']
# 等待 2.78 秒后继续...
#
# ==============================
# 处理 重庆 第 7/11 页
# ==============================
# 正在爬取: https://www.ricedata.cn/variety/identified/isqy_7.htm
# 使用编码: gbk
# 表格HTML片段: <table cellpadding="2" cellspacing="0" style="font-size:13; font-family:Times New Roman; border-top:solid black 2px; border-bottom:solid black 2px" width="1200"><tr align="left"><td height="30" width="50"><b>序号</b></td><td height="30" width="120"><b>品种名称</b></td><td><b>亲本来源（"×"前为母本）</b></td><td width="150"><b>类型</b></td><td><b>原产地/选育单位</b></td><td><b>审定编号</b></td></tr><caption style="text-align:right; font-size:13px; padding-top:15px;color: red"><b>重庆市历年审定品种 357 个：<a href="isqy_1.htm" style="fon...
# 找到有效表头: ['序号', '品种名称', '亲本来源（"×"前为母本）', '类型', '原产地/选育单位', '审定编号']
# 获取到 35 条记录
# 已爬取第 7/11 页，获取 35 条记录
# 前3条数据样例:
# 1. ['211', '渝香糯1号', '渝糯优16号×香糯119', '籼型常规稻', '重庆再生稻研究中心等', '渝审稻2012015', '重庆']
# 2. ['212', '金糯优998', '金糯3A×糯恢998', '籼型三系杂交稻', '重庆市瑞丰种业有限责任公司', '渝审稻2012014', '重庆']
# 3. ['213', '冈优916', '冈901A×蜀恢2516', '籼型三系杂交稻', '重庆金穗种业有限责任公司等', '渝审稻2012013', '重庆']
# 等待 2.46 秒后继续...
#
# ==============================
# 处理 重庆 第 8/11 页
# ==============================
# 正在爬取: https://www.ricedata.cn/variety/identified/isqy_8.htm
# 使用编码: gbk
# 表格HTML片段: <table cellpadding="2" cellspacing="0" style="font-size:13; font-family:Times New Roman; border-top:solid black 2px; border-bottom:solid black 2px" width="1200"><tr align="left"><td height="30" width="50"><b>序号</b></td><td height="30" width="120"><b>品种名称</b></td><td><b>亲本来源（"×"前为母本）</b></td><td width="150"><b>类型</b></td><td><b>原产地/选育单位</b></td><td><b>审定编号</b></td></tr><caption style="text-align:right; font-size:13px; padding-top:15px;color: red"><b>重庆市历年审定品种 357 个：<a href="isqy_1.htm" style="fon...
# 找到有效表头: ['序号', '品种名称', '亲本来源（"×"前为母本）', '类型', '原产地/选育单位', '审定编号']
# 获取到 35 条记录
# 已爬取第 8/11 页，获取 35 条记录
# 前3条数据样例:
# 1. ['246', '冈优618', '冈46A×R618', '籼型三系杂交稻', '湖南隆平种业有限公司', '渝审稻2010001', '重庆']
# 2. ['247', '中9优804', '中9A×涪恢9804', '籼型三系杂交稻', '重庆市涪陵区农业科学研究所', '渝审稻2009009', '重庆']
# 3. ['248', 'Ⅱ优缙9', 'Ⅱ-32A×缙恢13号', '籼型三系杂交稻', '西南大学', '渝审稻2009008', '重庆']
# 等待 2.19 秒后继续...
#
# ==============================
# 处理 重庆 第 9/11 页
# ==============================
# 正在爬取: https://www.ricedata.cn/variety/identified/isqy_9.htm
# 使用编码: gbk
# 表格HTML片段: <table cellpadding="2" cellspacing="0" style="font-size:13; font-family:Times New Roman; border-top:solid black 2px; border-bottom:solid black 2px" width="1200"><tr align="left"><td height="30" width="50"><b>序号</b></td><td height="30" width="120"><b>品种名称</b></td><td><b>亲本来源（"×"前为母本）</b></td><td width="150"><b>类型</b></td><td><b>原产地/选育单位</b></td><td><b>审定编号</b></td></tr><caption style="text-align:right; font-size:13px; padding-top:15px;color: red"><b>重庆市历年审定品种 357 个：<a href="isqy_1.htm" style="fon...
# 找到有效表头: ['序号', '品种名称', '亲本来源（"×"前为母本）', '类型', '原产地/选育单位', '审定编号']
# 获取到 35 条记录
# 已爬取第 9/11 页，获取 35 条记录
# 前3条数据样例:
# 1. ['281', '渝优6号', '金23A×渝恢5号', '籼型三系杂交稻', '重庆市作物研究所', '渝审稻2006019', '重庆']
# 2. ['282', '蓉优8号', '渝6A×渝恢5号', '籼型三系杂交稻', '重庆市作物研究所等', '渝审稻2006018', '重庆']
# 3. ['283', '万优2号', '宜香1A×万恢355', '籼型三系杂交稻', '重庆三峡农业科学研究所', '渝审稻2006017', '重庆']
# 等待 2.61 秒后继续...
#
# ==============================
# 处理 重庆 第 10/11 页
# ==============================
# 正在爬取: https://www.ricedata.cn/variety/identified/isqy_10.htm
# 使用编码: gbk
# 表格HTML片段: <table cellpadding="2" cellspacing="0" style="font-size:13; font-family:Times New Roman; border-top:solid black 2px; border-bottom:solid black 2px" width="1200"><tr align="left"><td height="30" width="50"><b>序号</b></td><td height="30" width="120"><b>品种名称</b></td><td><b>亲本来源（"×"前为母本）</b></td><td width="150"><b>类型</b></td><td><b>原产地/选育单位</b></td><td><b>审定编号</b></td></tr><caption style="text-align:right; font-size:13px; padding-top:15px;color: red"><b>重庆市历年审定品种 357 个：<a href="isqy_1.htm" style="fon...
# 找到有效表头: ['序号', '品种名称', '亲本来源（"×"前为母本）', '类型', '原产地/选育单位', '审定编号']
# 获取到 35 条记录
# 已爬取第 10/11 页，获取 35 条记录
# 前3条数据样例:
# 1. ['316', '西农优1号', '金23A×缙恢10号', '籼型三系杂交稻', '西南农业大学', '渝审稻2004007号', '重庆']
# 2. ['317', '西农优7号', 'Ⅱ-32A×R27', '籼型三系杂交稻', '西南农业大学', '渝审稻2004006号', '重庆']
# 3. ['318', '宜香3003', '宜香1A×宜恢3003', '籼型三系杂交稻', '四川省宜宾市农业科学院', '渝审稻2004005号', '重庆']
# 等待 1.45 秒后继续...
#
# ==============================
# 处理 重庆 第 11/11 页
# ==============================
# 正在爬取: https://www.ricedata.cn/variety/identified/isqy_11.htm
# 使用编码: gbk
# 表格HTML片段: <table cellpadding="2" cellspacing="0" style="font-size:13; font-family:Times New Roman; border-top:solid black 2px; border-bottom:solid black 2px" width="1200"><tr align="left"><td height="30" width="50"><b>序号</b></td><td height="30" width="120"><b>品种名称</b></td><td><b>亲本来源（"×"前为母本）</b></td><td width="150"><b>类型</b></td><td><b>原产地/选育单位</b></td><td><b>审定编号</b></td></tr><caption style="text-align:right; font-size:13px; padding-top:15px;color: red"><b>重庆市历年审定品种 357 个：<a href="isqy_1.htm" style="fon...
# 找到有效表头: ['序号', '品种名称', '亲本来源（"×"前为母本）', '类型', '原产地/选育单位', '审定编号']
# 获取到 7 条记录
# 已爬取第 11/11 页，获取 7 条记录
# 前3条数据样例:
# 1. ['351', '小粒粘', 'IR15429-680-5', '籼型常规稻', '重庆市作物所', '渝农作品审稻第7号', '重庆']
# 2. ['352', 'D优704', 'D汕A×704', '籼型三系杂交稻', '重庆市作物所', '渝农作品审稻第6号', '重庆']
# 3. ['353', '704', '渝矮×明恢63', '籼型常规稻', '重庆市作物所', '渝农作品审稻第5号', '重庆']
# 等待 1.54 秒后继续...
# 已保存 357 条数据到 rice_data/重庆水稻数据.csv
# 已完成 重庆 的数据采集，获取 357 条记录
# 等待 4.67 秒后处理下一个省份...
#
# ==================================================
# 数据采集完成！共获取 22846 条记录
# 处理了 31 个省份
# 数据保存在 rice_data 文件夹中
# ==================================================
